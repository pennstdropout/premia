# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import dask.dataframe as dd
from dask.distributed import Client
import wrds
import os
from statsmodels.sandbox.regression import gmm
from statsmodels.api import OLS

# %%
# Import data

def request_wrds(path: str,
                 start_date: pd.Timestamp,
                 end_date: pd.Timestamp) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame):
    with wrds.Connection() as db:
        df_s12 = db.raw_sql(f'''
            SELECT *
            FROM tfn.s12
            WHERE fdate >= '{start_date}' AND fdate <= '{end_date}'
        ''', date_cols=['fdate'])
        df_s12.to_csv(f'{path}s12.csv')

        df_s12type5 = db.raw_sql(f'''
                    SELECT *
                    FROM tfn.s12type5
                    WHERE fdate >= '{start_date}' AND fdate <= '{end_date}'
                ''', date_cols=['fdate'])
        df_s12type5.to_csv(f'{path}df_s12type5.csv')
    
        df_s34 = db.raw_sql(f'''
            SELECT *
            FROM tfn.s34
            WHERE fdate >= '{start_date}' AND fdate <= '{end_date}'
        ''', date_cols=['fdate'])
        df_s34.to_csv(f'{path}s34.csv')

        df_beta = db.raw_sql(f'''
            SELECT *
            FROM beta.ff3
            WHERE date >= '{start_date}' AND date <= '{end_date}'
        ''', date_cols=['date'])
        df_beta.to_csv(f'{path}security.csv')

        df_security = db.raw_sql(f'''
            SELECT *
            FROM crspm.crspm_stock
            WHERE date >= '{start_date}' AND date <= '{end_date}'
        ''', date_cols=['date'])
        df_security.to_csv(f'{path}security.csv')

        return df_s12, df_s34, df_security


def dask_read(path: str) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame):
    try:
        df_s12 = dd.read_csv(f'{path}s12.csv', encoding='ISO-8859-1')
        log_import_s12(df_s12)

        df_s12type5 = dd.read_csv(f'{path}s12type5.csv', encoding='ISO-8859-1')
        log_import_s12type5(df_s12type5)

        df_s34 = dd.read_csv(f'{path}s34.csv', encoding='ISO-8859-1')
        log_import_s34(df_s34)

        df_beta = dd.read_csv(f'{path}beta.csv', encoding='ISO-8859-1')
        log_import_beta(df_beta)

        df_security = dd.read_csv(f'{path}security.csv', encoding='ISO-8859-1')
        log_import_security(df_security)

        return df_s12, df_s12type5, df_s34, df_beta, df_security
    
    except FileNotFoundError:
        return request_wrds(path, start_date, end_date)


def pandas_read(path: str) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame):
    try:
        df_s12 = pd.read_csv(f'{path}s12.csv', encoding='ISO-8859-1', low_memory=False)
        log_import_s12(df_s12)

        df_s12type5 = pd.read_csv(f'{path}s12type5.csv', encoding='ISO-8859-1', low_memory=False)
        log_import_s12type5(df_s12type5)

        df_s34 = pd.read_csv(f'{path}s34.csv', encoding='ISO-8859-1', low_memory=False)
        log_import_s34(df_s34)

        df_beta = pd.read_csv(f'{path}beta.csv', encoding='ISO-8859-1', low_memory=False)
        log_import_beta(df_beta)

        df_security = pd.read_csv(f'{path}security.csv', encoding='ISO-8859-1', low_memory=False)
        log_import_security(df_security)

        return df_s12, df_s12type5, df_s34, df_beta, df_security
    
    except FileNotFoundError:
        return request_wrds(path, start_date, end_date)


def clean_imports(df_s12,
                  df_s12type5,
                  df_s34,
                  df_beta,
                  df_security,
                  start_date,
                  end_date
                  ) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame):

    df_s12_clean = clean_s12(df_s12, start_date, end_date)
    log_clean_s12(df_s12_clean)

    df_s12type5_clean = clean_s12type5(df_s12type5, start_date, end_date)
    log_clean_s12type5(df_s12type5_clean)

    df_s34_clean = clean_s34(df_s34, start_date, end_date)
    log_clean_s34(df_s34_clean)

    df_beta_clean = clean_beta(df_beta, start_date, end_date)
    log_clean_beta(df_beta_clean)

    df_security_clean = clean_security(df_security, start_date, end_date)
    log_clean_security(df_security_clean)

    return df_s12_clean, df_s12type5_clean, df_s34_clean, df_beta_clean, df_security_clean


def clean_s12(df: pd.DataFrame, start_date: pd.Timestamp, end_date: pd.Timestamp) -> pd.DataFrame:
    columns = [
        'fundno',
        'rdate',
        'cusip',
        'shares'
    ]
    return (df[columns]
            .dropna(how='any', subset=['fundno', 'shares', 'cusip'])
            .rename(columns={
                'rdate': 'date',
                'fundno': 'inv_id',
                'cusip': 'asset_id'})
            .assign(date=lambda x: fix_date(x['date']))
            .loc[lambda x: (x['date'] >= start_date) & (x['date'] <= end_date)]
            .drop_duplicates(subset=['inv_id', 'date', 'asset_id'], keep='last'))


def clean_s12type5(df: pd.DataFrame, start_date: pd.Timestamp, end_date: pd.Timestamp) -> pd.DataFrame:
    return (df.rename(columns={'fdate': 'date', 'fundno': 'inv_id'})
            .assign(date=lambda x: fix_date(x['date']))
            .loc[lambda x: (x['date'] >= start_date) & (x['date'] <= end_date)]
            .dropna(how='any', subset=['inv_id', 'date']))


def clean_s34(df: pd.DataFrame, start_date: pd.Timestamp, end_date: pd.Timestamp) -> pd.DataFrame:
    columns = [
        'mgrno',
        'rdate',
        'typecode',
        'cusip',
        'shares'
    ]
    return (df[columns]
            .dropna(how='any', subset=['mgrno', 'rdate', 'cusip', 'shares'])
            .rename(columns={
                'rdate': 'date',
                'mgrno': 'inv_id',
                'cusip': 'asset_id'})
            .assign(date=lambda x: fix_date(x['date']))
            .loc[lambda x: (x['date'] >= start_date) & (x['date'] <= end_date)]
            .drop_duplicates(subset=['inv_id', 'date', 'asset_id'], keep='last'))


def clean_beta(df: pd.DataFrame, start_date: pd.Timestamp, end_date: pd.Timestamp) -> pd.DataFrame:
    columns=[
        'PERMNO',
        'DATE',
        'b_mkt',
        'b_smb',
        'b_hml'
    ]
    offset = 6
    return (df[columns]
            .dropna()
            .rename(columns={
                'DATE': 'date',
                'PERMNO':'permno'})
            .assign(date=lambda x: fix_date(x['date']) + offset)
            .loc[lambda x: (x['date'] >= start_date) & (x['date'] <= end_date)]
            .drop_duplicates(subset=['date', 'permno'], keep='last'))


def clean_security(df: pd.DataFrame, start_date: pd.Timestamp, end_date: pd.Timestamp) -> pd.DataFrame:
    columns = [
        'LPERMNO',
        'cusip',
        'datadate',
        'prccm',
        'trt1m',
        'cshoq'
    ]
    offset = 6
    return (df[columns]
            .rename(columns={
                'LPERMNO': 'permno',
                'cusip': 'asset_id',
                'prccm': 'prc',
                'cshoq': 'shrout',
                'datadate': 'date'})
            .assign(shrout=lambda x: x.groupby('asset_id')['shrout'].ffill() * 1000000,
                    asset_id=lambda x: x['asset_id'].apply(lambda s: s[:-1]),
                    date=lambda x: fix_date(x['date']) + offset)
            .dropna(how='any', subset=['asset_id', 'prc', 'shrout'])
            .loc[lambda x: (x['date'] >= start_date) & (x['date'] <= end_date)]
            .drop_duplicates(subset=['date', 'permno'], keep='last'))


# def fix_date(dates: pd.Series) -> pd.Series:
#     return pd.to_datetime(dates) + pd.offsets.MonthEnd(0)


def fix_date(dates: pd.Series) -> pd.Series:
    return pd.to_datetime(dates).dt.to_period(freq='M')

# %%
# Stocks Monthly

def merge_assets_factors(df_assets: pd.DataFrame, df_factors: pd.DataFrame) -> pd.DataFrame:
    df_merged = pd.merge(
        left=df_assets,
        right=df_factors,
        how='left',
        on=['date', 'permno'])

    df_merged_indexed = (df_merged
                         .assign(shrout=lambda x: x['shrout'].astype('int64'),
                                 date=lambda x: x['date'].dt.asfreq('Q'))
                         .drop_duplicates(subset=['date', 'asset_id'], keep='last')
                         .drop(columns=['permno']))

    log_asset_merge(df_merged_indexed)
    return df_merged_indexed


# Manager / Holdings

def match_fund_manager(df_fund: pd.DataFrame, df_manager: pd.DataFrame, df_key: pd.DataFrame) -> pd.DataFrame:
    df_fund_manager = (df_manager
                       .assign(shares=lambda x: x['shares'].astype('int64'),
                               date=lambda x: x['date'].dt.asfreq(freq='Q'))
                       .drop_duplicates(subset=['inv_id', 'date', 'asset_id'], keep='last'))
    
    log_holding_merge(df_fund_manager)
    return df_fund_manager


def construct_zero_holdings(df_fund_manager: pd.DataFrame, n_quarters: int) -> pd.DataFrame:
    
    def calc_inv_obs(df: pd.DataFrame) -> pd.DataFrame:
        date_diff = (df.groupby('inv_id')['date'].transform('max') - df['date']).apply(lambda x: x.n)
        min_diff = np.minimum(date_diff, n_quarters) + 1
        return min_diff
    
    def calc_asset_obs(df: pd.DataFrame) -> pd.DataFrame:
        date_diff = (df.sort_values('date')
                     .groupby(['inv_id', 'asset_id'])
                     ['date']
                     .diff(periods=1)
                     .fillna(pd.DateOffset(n=1))
                     .apply(lambda x: x.n))
        min_diff = np.minimum(date_diff, df['inv_obs'])
        return min_diff.apply(lambda x: list(range(x)))
    
    df_holding = (df_fund_manager
                  .assign(inv_obs=lambda x: calc_inv_obs(x),
                          asset_obs=lambda x: calc_asset_obs(x))
                  .explode('asset_obs')
                  .assign(asset_obs=lambda x: x['asset_obs'].astype('int8'),
                          mask=lambda x: x['asset_obs'] == 0,
                          shares=lambda x: x['shares'] * x['mask'],
                          date=lambda x: x['date'] + x['asset_obs'])
                  .drop(columns=['inv_obs', 'asset_obs', 'mask']))
        
    log_zero_holdings(df_holding)
    return df_holding

def merge_holding_factor(df_holding: pd.DataFrame, df_asset: pd.DataFrame) -> pd.DataFrame:
    df_merged = pd.merge(
        left=df_holding,
        right=df_asset,
        how='left',
        on=['date', 'asset_id'])

    df_holding_factor = (df_merged
                         .assign(shares=lambda x: np.minimum(x['shares'], x['shrout']),
                                 holding=lambda x: x['prc'] * x['shares'] / 1000000,
                                 me=lambda x: x['prc'] * x['shrout'] / 1000000,
                                 typecode=lambda x: x['typecode'].fillna(0).astype('int8'))
                         .dropna(subset='holding'))
    
    log_holding_factor_merge(df_holding_factor)
    return df_holding_factor


def drop_unsused_inv_asset(df_holding_factor: pd.DataFrame) -> pd.DataFrame:
    df_dropped = (df_holding_factor
                  .assign(Tinv_shares=lambda x: x.groupby(['inv_id', 'date'])['shares'].transform('sum'),
                          Tasset_shares=lambda x: x.groupby(['date', 'asset_id'])['shares'].transform('sum'),
                          mask=lambda x: (x['Tinv_shares'] == 0) | (x['Tasset_shares'] == 0))
                  .loc[lambda x: ~x['mask']]
                  .drop(columns=['Tinv_shares', 'Tasset_shares', 'mask']))
    
    log_drop_unused(df_dropped)
    return df_dropped


def create_household_sector(df_dropped: pd.DataFrame) -> pd.DataFrame:
    df_household = (df_dropped
                      .groupby(['date', 'asset_id'], as_index=False)
                      .agg({
                        'shares': 'sum',
                        'prc': 'last',
                        'shrout': 'last',
                        'b_mkt': 'last',
                        'b_smb': 'last',
                        'b_hml': 'last',
                        'holding': 'sum',
                        'me': 'last'})
                      .assign(shares=lambda x: np.maximum(x['shrout'] - x['shares'], 0),
                              holding=lambda x: np.maximum(x['me'] - x['holding'], 0),
                              inv_id=0,
                              typecode=0))
    
    log_household_sector(df_household)
    df_concat = pd.concat([df_dropped, df_household])
    return df_concat

# %%
# Data

def partition_outside_asset(df_household: pd.DataFrame) -> pd.DataFrame:
    df_outside = (df_household
                  .assign(out_mask=lambda x: x.isna().any(axis=1),
                          out_holding=lambda x: x['holding'] * x['out_mask']))
    
    log_outside_asset(df_outside)
    return df_outside


def calc_inv_aum(df_outside: pd.DataFrame) -> pd.DataFrame:
    df_grouped = df_outside.groupby(['inv_id', 'date'])
    
    df_inv_aum = (df_outside
                  .assign(aum=lambda x: df_grouped['holding'].transform('sum'),
                          out_aum=lambda x: df_grouped['out_holding'].transform('sum'),
                          out_weight=lambda x: x['out_aum'] / x['aum']))

    log_inv_aum(df_inv_aum)
    return df_inv_aum


def agg_small_inv(df_inv_aum: pd.DataFrame) -> pd.DataFrame:
    df_agg = (df_inv_aum
              .assign(small_mask=lambda x: (x['aum'] < 10) | (x['out_weight'] == 0) | (x['out_weight'] == 1),
                      inv_id=lambda x: ~x['small_mask'] * x['inv_id'],
                      hh_mask=lambda x: x['inv_id'] == 0))

    df_grouped = df_agg.groupby(['inv_id', 'date', 'asset_id'])
    
    df_agg = (df_agg
              .assign(Tshares=lambda x: df_grouped['shares'].transform('sum'),
                      Tholding=lambda x: df_grouped['holding'].transform('sum'),
                      shares=lambda x: np.where(x['hh_mask'], x['Tshares'], x['shares']),
                      holding=lambda x: np.where(x['hh_mask'], x['Tholding'], x['holding']))
              .drop(columns=['Tshares', 'Tholding']))
    
    df_grouped = df_agg.groupby(['inv_id', 'date'])
    
    df_agg = (df_agg
              .assign(Taum=lambda x: df_grouped['holding'].transform('sum'),
                      Tout_aum=lambda x: df_grouped['out_holding'].transform('sum'),
                      aum=lambda x: np.where(x['hh_mask'], x['Taum'], x['aum']),
                      out_aum=lambda x: np.where(x['hh_mask'], x['Tout_aum'], x['out_aum']),
                      x_holding=lambda x: df_grouped['holding'].transform('count'),
                      n_holding=lambda x: x['x_holding'] - df_grouped['out_mask'].transform('sum'),
                      equal_alloc=lambda x: ~x['hh_mask'] * x['aum'] / (1 + x['x_holding']),
                      drop_mask=lambda x: x['small_mask'] | x['out_mask'])
              .loc[lambda x: ~x['drop_mask']]
              .drop(columns=['Taum', 'Tout_aum', 'out_mask', 'out_holding', 'out_weight', 'small_mask', 'drop_mask', 'hh_mask']))
    
    log_agg_small_inv(df_agg)
    return df_agg
    

def bin_inv(df_inv_aum: pd.DataFrame, min_n_holding: int) -> (pd.DataFrame, pd.DataFrame):
    
    def calc_bin(df_type_date: pd.DataFrame) -> pd.Series:
        typecode = df_type_date['typecode'].iloc[0]
        n_holding = (df_type_date['holding'] > 0).sum()
        n_bins = np.floor(n_holding / (2 * min_n_holding)).astype(int)
        idx = df_type_date.index
        
        if (n_bins <= 1) | (n_holding >= min_n_holding) | (typecode == 0):
            return pd.Series(0, index=idx)
        else:
            return pd.Series(pd.qcut(x=df_type_date['aum'], q=n_bins, labels=False), index=idx)
    
    
    df_binned = (df_inv_aum
                 .reset_index(drop=True)
                 .assign(bin=lambda x: x.groupby(['typecode', 'date']).apply(calc_bin).reset_index(drop=True))
                 .assign(bin=lambda x: x.groupby(['date', 'typecode', 'bin']).ngroup()))
    
    log_bins(df_binned)
    return df_binned


def calc_instrument(df_binned: pd.DataFrame) -> pd.DataFrame:    
    df_instrument = (df_binned
                     .assign(total_alloc=lambda x: x.groupby(['date', 'asset_id'])['equal_alloc'].transform('sum'),
                             iv_me=lambda x: x['total_alloc'] - x['equal_alloc'])
                     .drop(columns=['total_alloc', 'equal_alloc']))
    
    log_instrument(df_instrument)
    return df_instrument


def dask_calc_instrument(df_binned: pd.DataFrame) -> pd.DataFrame:
    df_binned = dd.from_pandas(df_binned.set_index('date'), npartitions=32)
    
    df_instrument = (df_binned
                     .assign(total_alloc=lambda x: x.groupby(['date', 'asset_id'])['equal_alloc'].transform('sum', meta=pd.Series(dtype='float64')),
                             iv_me=lambda x: x['total_alloc'] - x['equal_alloc'])
                     .drop(columns=['total_alloc', 'equal_alloc'])
                     .compute()
                     .reset_index())
    
    log_instrument(df_instrument)
    return df_instrument


def calc_holding_weights(df_instrument: pd.DataFrame) -> pd.DataFrame:
    mask = (df_instrument['iv_me'] > 0)

    df_weights = (df_instrument.loc[mask]
                 .assign(ln_me=lambda x: np.log(x['me']),
                         ln_iv_me=lambda x: np.log(x['iv_me']),
                         weight=lambda x: x['holding'] / x['aum'],
                         rweight=lambda x: x['holding'] / x['out_aum'],
                         ln_rweight=lambda x: np.log(x['rweight'].mask(x['rweight'] == 0, np.NaN)),
                         mean_ln_rweight=lambda x: x.groupby(['inv_id', 'date'])['ln_rweight'].transform('mean'),
                         const=1,
                         pct_uni_held=lambda x: np.log(x['n_holding']) - np.log(x['x_holding']))
                .drop(columns=['me', 'iv_me']))
    
    log_holding_weights(df_weights)
    return df_weights

# %%
# Estimation

def bound_float(arr: np.array) -> float:
    ln_bound = 709.7827
    return np.minimum(np.maximum(arr, -ln_bound), ln_bound)


def momcond_L(params: np.array, exog: np.array) -> np.array:
    upper_bound = 0.999
    exog = exog.T
    
    beta_ln_me = params[0]
    beta_characteristics = params[1:]
    
    ln_me = exog[0]
    mean_ln_rweight = exog[1]
    arr_characteristics = exog[2:]
    
    ln_me_term = (upper_bound - np.exp(-1 * beta_ln_me)) * ln_me
    characteristics_term = np.dot(beta_characteristics, arr_characteristics)
    pred_weight = ln_me_term + characteristics_term + mean_ln_rweight
    
    return pred_weight


def fit_inv_date_L(df_inv_date: pd.DataFrame, characteristics: list, params: list,) -> gmm.GMMResults:
    df_inv_date = df_inv_date.dropna(subset='ln_rweight')
    
    exog = np.asarray(df_inv_date[['ln_me', 'mean_ln_rweight'] + characteristics])
    instrument = np.asarray(df_inv_date[['ln_iv_me', 'mean_ln_rweight'] + characteristics])
    n = exog.shape[0]
    endog = np.asarray(df_inv_date['ln_rweight'] - df_inv_date['pct_uni_held'])
    start_params = np.zeros(len(params))
    w0inv = np.dot(instrument.T, instrument) / n
    
    try:
        model = gmm.NonlinearIVGMM(
            endog=endog,
            exog=exog,
            instrument=instrument, 
            func=momcond_L)
        result = model.fit(
            start_params=start_params,
            maxiter=0,
            inv_weights=w0inv)
        # log_results(result, params)
        return result
    
    except np.linalg.LinAlgError:
        print('Linear Algebra Error')
        return None
        
        
def estimate_model_L(df_weights: pd.DataFrame, characteristics: list, params: list, min_n_holding: int) -> pd.DataFrame:
    
    mask = df_weights['n_holding'] >= min_n_holding
    
    df_institutions = (df_weights
                       .loc[mask]
                       .set_index(['inv_id', 'date'])
                       .assign(gmm_result=lambda x: x.groupby(['inv_id', 'date']).apply(lambda y: fit_inv_date_L(y, characteristics, params)))
                       .reset_index())
    
    df_bins = (df_weights
               .loc[~mask]
               .set_index(['bin', 'date'])
               .assign(gmm_result=lambda x: x.groupby(['bin', 'date']).apply(lambda y: fit_inv_date_L(y, characteristics, params)))
               .reset_index())
    
    df_model = pd.concat([df_institutions, df_bins])
    log_params(df_model)
    return df_model


def momcond_NL(params: np.array, exog: np.array) -> np.array:
    upper_bound = 0.9999
    exog = exog.T
    
    beta_ln_me = bound_float(params[0])
    beta_characteristics = params[1:]
    
    ln_me = exog[0]
    rweight = exog[1]
    mean_ln_rweight = exog[2]
    arr_characteristics = exog[3:]
    
    ln_me_term = (upper_bound - np.exp(-1 * beta_ln_me)) * ln_me
    characteristics_term = np.dot(beta_characteristics, arr_characteristics)
    pred_ln_rweight = bound_float(ln_me_term + characteristics_term + mean_ln_rweight)
    pred_rweight = np.exp(-1 * pred_ln_rweight)
    
    return rweight * pred_rweight


def fit_inv_date_NL(df_inv_date: pd.DataFrame, characteristics: list, params: list) -> gmm.GMMResults:
    exog = np.asarray(df_inv_date[['ln_me', 'rweight', 'mean_ln_rweight'] + characteristics])
    instrument = np.asarray(df_inv_date[['ln_iv_me', 'rweight', 'mean_ln_rweight'] + characteristics])
    n = exog.shape[0]
    endog = np.ones(n)
    
    try:
        model = gmm.NonlinearIVGMM(
            endog=endog,
            exog=exog,
            instrument=instrument, 
            func=momcond_NL)
        w0inv = np.dot(instrument.T, instrument) / n
        start_params = np.zeros(len(params))
        result = model.fit(
            start_params=start_params,
            maxiter=100,
            inv_weights=w0inv)
        # log_results(result, params)
        return result
    
    except np.linalg.LinAlgError:
        print('Linear Algebra Error')
        return None
        
        
def estimate_model_NL(df_weights: pd.DataFrame, characteristics: list, params: list) -> pd.DataFrame:
    
    mask = df_weights['n_holding'] >= min_n_holding
    
    df_institutions = (df_weights
                       .loc[mask]
                       .set_index(['inv_id', 'date'])
                       .assign(gmm_result=lambda x: x.groupby(['inv_id', 'date']).apply(lambda y: fit_inv_date_L(y, characteristics, params)))
                       .reset_index())
    
    df_bins = (df_weights
               .loc[~mask]
               .set_index(['bin', 'date'])
               .assign(gmm_result=lambda x: x.groupby(['bin', 'date']).apply(lambda y: fit_inv_date_L(y, characteristics, params)))
               .reset_index())
    
    df_model = pd.concat([df_institutions, df_bins])
    log_params(df_model)
    return df_model


def calc_latent_demand_L(df_model: pd.DataFrame, characteristics: list, params: list) -> pd.DataFrame:
    
    def unpack_result(result: gmm.GMMResults) -> list:
        return result.params

    def unpack_params(df: pd.DataFrame) -> pd.DataFrame:
        df[params] = pd.DataFrame(df['lst_params'].tolist(), index=df.index)
        return df
    
    
    upper_bound = 0.9999
    
    df_results = (df_model
                  .dropna()
                  .assign(lst_params=lambda x: x['gmm_result'].apply(unpack_result))
                  .pipe(unpack_params)
                  .drop(columns='lst_params')
                  .assign(beta_ln_me=lambda x: upper_bound - np.exp(-1 * x['beta_ln_me']),
                          beta_const=lambda x: x['beta_const'] + x['mean_ln_rweight'],
                          pred_ln_rweight=lambda x: np.einsum('ij,ij->i', x[['ln_me'] + characteristics], x[params]),
                          latent_demand=lambda x: x['ln_rweight'] - x['pred_ln_rweight'])
                  .drop(columns=['pct_uni_held', 'gmm_result', 'pred_ln_rweight']))
    
    log_latent_demand(df_results)
    return df_results

# %%
# Liquidity

def calc_coliquidity_matrix(df_date: pd.DataFrame) -> pd.Series:
    df_asset_grouped = df_date.groupby('asset_id')
    n_assets = len(df_asset_grouped)
    print(n_assets)

    df_liquid = (df_date
                 .assign(first=lambda x: df_asset_grouped.cumcount() == 0,
                         total_holding=lambda x: df_asset_grouped['holding'].transform('sum'),
                         share_of_holding=lambda x: x['holding'] / x['total_holding'],
                         row=lambda x: df_asset_grouped.ngroup())
                 .sort_values('row'))
    
    Zmat = np.empty(shape=(n_assets, n_assets))
    Amat = np.empty(shape=(n_assets, n_assets))
    
    for col in range(n_assets):
        df_liquid = df_liquid.assign(mask=lambda x: x['row'] == col,
                                     mask_weight=lambda x: x['mask'] * x['weight'],
                                     rcweight = lambda x: x['mask'] - x.groupby('inv_id')['mask_weight'].transform('max'),
                                     Zcol=lambda x: x['beta_ln_me'] * x['share_of_holding'] * x['rcweight'],
                                     Acol=lambda x: x['share_of_holding'] * x['rcweight'])
        Zmat[col] = df_liquid.groupby('asset_id')['Zcol'].sum()
        Amat[col] = df_liquid.groupby('asset_id')['Acol'].sum()
        print('Added asset ', col)

    # types = df_date['typecode'].unique()
    # for i, t in enumerate(types):
    #     Bcol_name = 'Bcol_' + str(t)        
    #     mask = df_liquid['typecode'] == t
    #     df_liquid[Bcol_name] = mask * df_liquid['Acol']
    # 
    # for t in types:
    #     Bcol_name = 'Bcol_' + str(t)
    #     
    #     n_type = df_asset_grouped.apply(lambda x: (x['typecode'] == t).sum())
    #     df_matrix[Bcol_name] = df_asset_grouped[Bcol_name].sum() / np.maximum(n_type, 1)
    
    I = np.identity(n_assets)
    liquidity_matrixA = np.linalg.solve(I - Zmat, Amat)
    price_impact = np.diagonal(liquidity_matrixA)
    
    idx = df_liquid.set_index('row')['asset_id'].to_dict()
    sr_liquid = pd.Series(price_impact, index=idx, name='price_impact')
    
    return sr_liquid


def calc_price_elasticity(df_results: pd.DataFrame) -> pd.DataFrame:
    mask = df_results['holding'] > 0
    
    df_liquidity = (df_results
                    .loc[mask]
                    .groupby('date')
                    .apply(calc_coliquidity_matrix))
    
    log_liquidity(df_liquidity)
    return df_liquidity
    

def graph_liquidity(df_liquidity: pd.DataFrame):
    df_fig = (df_liquidity
              .groupby('date')
              .agg({'p10': lambda x: np.quantile(x['price_impact'], q=0.1),
                    'p50': lambda x: np.quantile(x['price_impact'], q=0.5),
                    'p90': lambda x: np.quantile(x['price_impact'], q=0.9)})
              .stack()
              .reset_index(name='stat'))
    
    g = sns.relplot(data=df_fig,
                    x='date',
                    y='p10',
                    hue='stat',
                    kind='line')
    g.set_axis_labels('Date', 'Price Impact')
    g.legend()
    g.despine()
    plt.savefig(os.path.join(figure_path, f'price_elasticity.png'))
    return df_liquidity

# %%
# Decomposition

def equillibrium_loop(df_loop: pd.DataFrame) -> pd.DataFrame:

    for i in range(1000):
        df_loop = (df_loop
                   .assign(weightN=lambda x: np.exp(x['loop_beta_ln_me'] * x['loop_ln_prc']) + x['loop_latent'],
                           weightD=lambda x: x.groupby(['inv_id', 'date'])['weightN'].transform('sum'),
                           weight=lambda x: x['weightN'] / (1 + x['weightD']),
                           holding=lambda x: x['weight'] * x['loop_aum'],
                           demand=lambda x: x.groupby(['inv_id', 'date'])['holding'].transform('sum'),
                           Ddemand_a=lambda x: x['loop_beta_ln_me'] * x['loop_aum'] * x['weight'] * (1 - x['weight']) / x['demand'],
                           Ddemand_b=lambda x: x.groupby(['date', 'asset_id'])['Ddemand_a'].transform('sum'),
                           Ddemand_c=lambda x: 1 / (1 - np.minimum(0, x['Ddemand_b'])),
                           gap=lambda x: np.log(x['demand']) - x['loop_ln_price'] - x['loop_ln_shrout']))
        
        gap = max(abs(df_loop['gap'].min()), abs(df_loop['gap'].max()))
        
        if i == 999:
            print(f'Equilibrium did not converge after 1000 iterations')
            print(f'Gap:  ', gap)
        
        if gap < 0.00001:
            print(f'Equilibrium converged after {i} iterations')
            df_loop = df_loop.assign(loop_ln_prc=lambda x: x.groupby('asset_id')['loop_ln_prc'].transform('min'))
    
    return df_loop


def run_counterfactuals(df_date: pd.DataFrame, characteristics: list, params: list) -> pd.DataFrame:
    for i in range(1, 6):
        if i <= 4:
            df_date = df_date.assign(loop_ln_prc=lambda x: x['lag_ln_prc'],
                                     loop_ln_shrout=lambda x: x['lag_ln_shrout'])
        else:
            df_date = df_date.assign(loop_ln_prc=lambda x: x['prc'],
                                     loop_ln_shrout=lambda x: x['shrout'])
    
        if i == 1:
            for char in characteristics:
                df_date['loop_' + char] = df_date['lag_' + char]
        elif i <= 4:
            for char in characteristics:
                df_date['loop_' + char] = df_date['lag_' + char]
        else:
            for char in characteristics:
                df_date['loop_' + char] = df_date[char]
                
        if i <= 2:
            df_date['loop_aum'] = df_date['lag_aum']
        elif i <= 4:
            df_date['loop_aum'] = df_date['aum']
        else:
            df_date['loop_aum'] = df_date['aum']
        
        if i <= 3:
            for param in params:
                df_date['loop_' + param] = df_date['lag_' + param]
        elif i <= 4:
            for param in params:
                df_date['loop_' + param] = df_date['lag_' + param]
        else:
            for param in params:
                df_date['loop_' + param] = df_date[param]
        
        loop_chars = ['loop_' + char for char in characteristics]
        loop_params = ['loop_' + param for param in params]
        if i <= 4:
            df_date = df_date.assign(loop_latent=lambda x: np.einsum('ij,ij->i', df_date[['loop_ln_shrout'] + loop_chars], df_date[loop_params]) + x['lag_latent_demand']) 
        else:
            df_date = df_date.assign(loop_latent=lambda x: np.einsum('ij,ij->i', df_date[['loop_ln_shrout'] + loop_chars], df_date[loop_params]) + x['latent_demand'])

    return df_date


def decompose_variance(df_results: pd.DataFrame, characteristics: list, params: list) -> pd.DataFrame:
    mask = df_results['holding'] > 0
    
    df_variance = (df_results
                   .loc[mask]
                   .assign(ln_prc=lambda x: np.log(x['prc']),
                           ln_shrout=lambda x: np.log(x['shrout'])))
    
    df_grouped = df_variance.groupby(['date', 'asset_id'])
    
    df_variance = (df_variance
                   .assign(lag_ln_prc=lambda x: df_grouped['ln_prc'].shift(4),
                           lag_ln_shrout=lambda x: df_grouped['ln_shrout'].shift(4),
                           lag_aum=lambda x: df_grouped['aum'].shift(4),
                           lag_latent=lambda x: df_grouped['latent_demand'].shift(4)))
    
    for char in characteristics:
        name = 'lag_' + char
        df_variance[name] = df_variance.groupby(['date', 'asset_id'])[char].shift(4)
    
    return df_variance

# %%
# Predictability

# %%
# Figures

def clean_figures(df_results: pd.DataFrame) -> pd.DataFrame:
    return (df_results
            .assign(date=lambda x: x['date'].dt.to_timestamp(),
                    typecode=lambda x: x['typecode'].apply(get_readable_typecode)))


def typecode_share_counts(df_figure: pd.DataFrame, figure_path: str):
    df_type_share = (df_figure
                     .groupby(['typecode', 'date'])
                     .agg({'aum': 'sum', 'n_holding': 'count'})
                     .assign(share=lambda x: x['aum'] / x['aum'].groupby('date').transform('sum')))
    
    g = sns.relplot(data=df_type_share, 
                    x='date', 
                    y='n_holding', 
                    hue='typecode', 
                    kind='line')
    g.set_axis_labels('Date', 'Number of Investors')
    g.despine()
    plt.savefig(os.path.join(figure_path, f'typecode_count.png'))
    
    g = sns.relplot(data=df_type_share, 
                    x='date', 
                    y='share', 
                    hue='typecode', 
                    kind='line')
    g.set_axis_labels('Date', 'Share of AUM')
    g.despine()
    plt.savefig(os.path.join(figure_path, f'typecode_share.png'))
    
    return df_inv_aum


def check_moment_condition(df_figures: pd.DataFrame, min_n_holding: int):
    mask = df_figures['n_holding'] >= min_n_holding
    df_mom = (df_figures
              .loc[mask]
              .groupby(['inv_id', 'date'])
              .agg({'latent_demand': 'mean'}))
    
    epsilon = 0.01
    mask = (df_mom['latent_demand'] > -epsilon) & (df_mom['latent_demand'] < epsilon)
    valid_rate = len(df_mom[mask]) / len(df_mom)
    print(f'Percentage of valid moments:  {100*valid_rate:.4f}%')
    
    g = sns.displot(
        data=df_mom,
        x='latent_demand'
    )
    g.set_axis_labels('Log Latent Demand', 'Frequency')
    g.despine()
    plt.savefig(os.path.join(figure_path, f'moment_condition.png'))
    
    return df_figures


def critical_value_test(df_figures: pd.DataFrame, characteristics: list, min_n_holding: int, figure_path: str):
    
    def iv_reg(df_inv_date: pd.DataFrame):
        y = df_inv_date['ln_me']
        X = df_inv_date[['ln_iv_me'] + characteristics]
        model = OLS(y, X)
        result = model.fit()
        t_stat = result.tvalues.iloc[0]
        
        return t_stat
    
    
    mask = df_figures['n_holding'] >= min_n_holding
    
    df_iv_a = (df_figures
               .loc[mask]
               .groupby(['inv_id', 'date'])
               .apply(iv_reg))
    
    df_iv_b = (df_figures
               .loc[~mask]
               .groupby(['bin', 'date'])
               .apply(iv_reg))
    
    df_iv = (pd.concat([df_iv_a, df_iv_b])
             .to_frame('t_stat')
             .groupby('date')
             .min())
    
    g = sns.relplot(data=df_iv,
                    x='date',
                    y='t_stat',
                    kind='line')
    g.refline(y=4.05, linestyle='--')
    g.set_axis_labels('Date', 'First stage t-statistic')
    g.despine()
    plt.savefig(os.path.join(figure_path, f'instrument_validity.png'))
    
    return df_figures


def test_index_fund(df_figures: pd.DataFrame, characteristics: list, params: list, indexfund_id: int, figure_path: str):
    mask = df_figures['inv_id'] == indexfund_id
    df_index_fund = (df_figures
                     .assign(ln_rweight=lambda x: x['ln_me'] + x['mean_ln_rweight'],
                             pct_uni_held=1)
                     .loc[mask])
    
    df_index_fund_model = (df_index_fund
                           .set_index(['inv_id', 'date'])
                           .assign(gmm_result=lambda x: x.groupby(['inv_id', 'date']).apply(lambda y: fit_inv_date_L(y, characteristics, params)))
                           .reset_index())
    df_index_fund_result = calc_latent_demand_L(df_index_fund_model, characteristics, params)
    cols = params + ['latent_demand']
    for param in cols:
        g = sns.relplot(data=df_index_fund_result,
                        x='date',
                        y=param,
                        kind='line')
        g.set_axis_labels('Date', f'{get_readable_param(param)}')
        g.despine()
        plt.ylim(-1, 1)
        plt.savefig(os.path.join(figure_path, f'index_fund_{param}.png'))

    return df_figures
    

def graph_type_params(df_results: pd.DataFrame, params: list, figure_path: str):
    df_types = df_results.copy()
    df_types[params] = df_types[params].apply(lambda x: x * df_results['aum'])
    df_types = (df_types
                .groupby(['typecode', 'date'])
                [params]
                .sum()
                .apply(lambda x: x / df_results.groupby(['typecode', 'date'])['aum'].sum()))
    
    for param in params:
        g = sns.relplot(data=df_types, 
                        x='date',
                        y=param,
                        hue='typecode',
                        kind='line')
        g.set_axis_labels('Date', f'{get_readable_param(param)}')
        g.legend.set_title('Institution Type')
        g.despine()
        plt.savefig(os.path.join(figure_path, f'{param}.png'))
        
    return df_results


def graph_std_latent_demand(df_figures: pd.DataFrame, figure_path: str):
    df_ld = (df_figures
         .groupby(['inv_id', 'date'])
         .agg({
            'latent_demand': 'std',
            'aum': 'last',
            'typecode': 'last'})
         .assign(latent_demand=lambda x: x['latent_demand'] * x['aum'])
         .groupby(['typecode', 'date'])
         .agg({
            'latent_demand': 'mean',
            'aum': 'sum'})
         .assign(latent_demand=lambda x: x['latent_demand'] / x['aum']))
    
    g = sns.relplot(data=df_ld, 
                    x='date',
                    y='latent_demand',
                    hue='typecode',
                    kind='line')
    g.set_axis_labels('Date', 'Standard Deviation of Latent Demand')
    g.legend.set_title('Institution Type')
    g.despine()
    plt.savefig(os.path.join(figure_path, f'std_latent_demand.png'))
    
    return df_results


def summary_tables(df_figures: pd.DataFrame):
    return df_figures


def get_param_cols(cols: list) -> list:
    return ['beta_' + col for col in cols]


def get_readable_param(name: str) -> str:
    return name.replace('_', ' ').title()


def get_readable_typecode(typecode: int):
    return dict_typecode[typecode]

# %%
# Log

def log_import_s12(df_s12: pd.DataFrame):
    dateindex_s12 = df_s12['rdate']
    print('Imported s12')
    print('Number of holdings:  ', len(df_s12))
    print('Earliest date:  ', min(dateindex_s12))
    print('Latest date:  ', max(dateindex_s12))


def log_import_s12type5(df_s12type5: pd.DataFrame):
    dateindex_s12type5 = df_s12type5['fdate']
    print()
    print('Imported s12type5')
    print('Number of holdings:  ', len(df_s12type5))
    print('Earliest date:  ', min(dateindex_s12type5))
    print('Latest date:  ', max(dateindex_s12type5))


def log_import_s34(df_s34: pd.DataFrame):
    dateindex_s34 = df_s34['rdate']
    print()
    print('Imported s34')
    print('Number of holdings:  ', len(df_s34))
    print('Earliest date:  ', min(dateindex_s34))
    print('Latest date:  ', max(dateindex_s34))


def log_import_beta(df_beta: pd.DataFrame):
    dateindex_ffm = df_beta['DATE']
    print()
    print('Imported betas')
    print('Number of dates:  ', len(df_beta))
    print('Earliest date:  ', min(dateindex_ffm))
    print('Latest date:  ', max(dateindex_ffm))


def log_import_security(df_security: pd.DataFrame):
    dateindex_security = df_security['datadate']
    print()
    print('Imported security')
    print('Number of holdings:  ', len(df_security))
    print('Earliest date:  ', min(dateindex_security))
    print('Latest date:  ', max(dateindex_security))


def log_clean_s12(df_s12_clean: pd.DataFrame):
    dateindex_s12 = df_s12_clean['date']
    print()
    print('Cleaned s12')
    print('Number of holdings:  ', len(df_s12_clean))
    print('Earliest date:  ', min(dateindex_s12))
    print('Latest date:  ', max(dateindex_s12))


def log_clean_s12type5(df_s12type5_clean: pd.DataFrame):
    dateindex_s12type5 = df_s12type5_clean['date']
    print()
    print('Cleaned s12type5')
    print('Number of firm/dates:  ', len(df_s12type5_clean))
    print('Earliest date:  ', min(dateindex_s12type5))
    print('Latest date:  ', max(dateindex_s12type5))


def log_clean_s34(df_s34_clean: pd.DataFrame):
    dateindex_s34 = df_s34_clean['date']
    print()
    print('Cleaned s34')
    print('Number of holdings:  ', len(df_s34_clean))
    print('Earliest date:  ', min(dateindex_s34))
    print('Latest date:  ', max(dateindex_s34))


def log_clean_beta(df_beta_clean: pd.DataFrame):
    dateindex_beta = df_beta_clean['date']
    print()
    print('Cleaned beta')
    print('Number of dates:  ', len(df_beta_clean))
    print('Earliest date:  ', min(dateindex_beta))
    print('Latest date:  ', max(dateindex_beta))


def log_clean_security(df_security_clean: pd.DataFrame):
    dateindex_security = df_security_clean['date']
    print()
    print('Cleaned security')
    print('Number of asset/dates:  ', len(df_security_clean))
    print('Earliest date:  ', min(dateindex_security))
    print('Latest date:  ', max(dateindex_security))


def log_holding_merge(df_merged: pd.DataFrame):
    print()
    print('Merged s12 and s34')
    print('Number of holdings:  ', len(df_merged))
    print()


def log_drop_unused(df_dropped: pd.DataFrame):
    print()
    print('Dropped unused investors/assets')
    print('Number of holdings:  ', len(df_dropped))
    print()


def log_asset_merge(df_merged: pd.DataFrame):
    print()
    print('Merged assets and factors')
    print('Number of assets/dates:  ', len(df_merged))
    print()


def log_holding_factor_merge(df_merged: pd.DataFrame):
    print()
    print('Merged holdings and factors')
    print('Number of investor/date/asset:  ', len(df_merged))
    print()


def log_household_sector(df_household: pd.DataFrame):
    print()
    print('Created household sector')
    print('Number of holdings:  ', len(df_household))


def log_outside_asset(df_outside: pd.DataFrame):
    print()
    print('Created outside asset')
    print('Number of outside holdings:  ', df_outside['out_mask'].sum())


def log_zero_holdings(df_holding: pd.DataFrame):
    print()
    print('Constructed zero holdings')
    print('Number of non-zero holdings:  ', sum(df_holding['shares'] > 0))
    print('Number of zero holdings:  ', sum(df_holding['shares'] == 0))


def log_inv_aum(df_inv_aum: pd.DataFrame):
    print()
    print('Calculated investor AUM')
    print('Number of investors:  ', df_inv_aum['inv_id'].nunique())


def log_agg_small_inv(df_agg: pd.DataFrame):
    print()
    print('Aggregated small investors')
    print('Number of investors:  ', df_agg['inv_id'].nunique())


def log_bins(df_binned: pd.DataFrame):
    print()
    print('Binned investors')
    print('Number of investors:  ', df_binned['inv_id'].nunique())
    print('Number of bins:  ', df_binned['bin'].nunique())


def log_inv_universe(df_inv_uni: pd.DataFrame):
    print()
    print('Created investment universe')
    print('Number of investors:  ', df_inv_uni['inv_id'].nunique())
    print('Average investment universe size:  ', df_inv_uni['uni_size'].mean())
    

def log_instrument(df_instrument: pd.DataFrame):
    print()
    print('Created market equity instrument')
    print('Number of valid instruments:  ', sum(df_instrument['iv_me'] > 0))
    print('Number of invalid instruments:  ', sum(df_instrument['iv_me'] == 0))
    

def log_holding_weights(df_model: pd.DataFrame):
    print()
    print('Calculated holding weights')
    print('Number of non-zero holdings:  ', sum(df_model['holding'] > 0))
    print('Number of zero holdings:  ', sum(df_model['holding'] == 0))


def log_results(result, params):
    print()
    print(result.summary(yname='Latent demand', xname=params))
    print()
    

def log_params(df_params: pd.DataFrame):
    print()
    print('Estimated parameters')
    print('Number of converged estimations:  ', sum(df_params['gmm_result'].notna()))
    print('Number of unconverged estimations:  ', sum(df_params['gmm_result'].isna()))
    
    
def log_latent_demand(df_results: pd.DataFrame):
    print()
    print('Calculated latent demand')
    print('Number of investors:  ', df_results['inv_id'].nunique())


def log_liquidity(df_liquidity: pd.DataFrame):
    print()
    print('Calculated price elasticity')


def log_variance(df_variance: pd.DataFrame):
    print()
    print('Decomposed variance')
    
    
def log_predictability(df_predictability: pd.DataFrame):
    print()
    print('Tested return predictability')

# %%
def main():
    
    client = Client()
    
    dfs = pandas_read(input_path)
    df_s12_clean, df_s12type5_clean, df_s34_clean, df_beta_clean, df_security_clean = clean_imports(
        *dfs,
        start_date,
        end_date
    )
    
    df_fund_manager = match_fund_manager(df_s12_clean, df_s34_clean, df_s12type5_clean)
    
    df_holding = (df_fund_manager
                  .pipe(construct_zero_holdings, n_quarters))
    
    df_asset = merge_assets_factors(df_security_clean, df_beta_clean)
    df_holding_factor = merge_holding_factor(df_holding, df_asset)
    
    df_results = (df_holding_factor
                 .pipe(drop_unsused_inv_asset)
                 .pipe(create_household_sector)
                 .pipe(partition_outside_asset)
                 .pipe(calc_inv_aum)
                 .pipe(agg_small_inv)
                 .pipe(bin_inv, min_n_holding)
                 .pipe(calc_instrument)
                 .pipe(calc_holding_weights)
                 .pipe(estimate_model_L, characteristics, params, min_n_holding)
                 .pipe(calc_latent_demand_L, characteristics, params))
    return df_results
    df_results.to_csv(os.path.join(output_path, 'df_results.csv'))
    
    df_figures = (df_results
                  .pipe(clean_figures)
                  .pipe(typecode_share_counts, figure_path)
                  .pipe(check_moment_condition, min_n_holding)
                  .pipe(critical_value_test, characteristics, figure_path)
                  .pipe(test_index_fund, characteristics, params, figure_path)
                  .pipe(graph_type_params, params, figure_path)
                  .pipe(graph_std_latent_demand, figure_path))

# %%
# Global parameters

sns.set_theme(style='ticks', palette=sns.color_palette('hls', 6), context='paper')

input_path = 'data/'
output_path = 'output/'
figure_path = 'figures/'

os.makedirs(output_path, exist_ok=True)
os.makedirs(figure_path, exist_ok=True)

start_date = pd.Period('2012-01')
end_date = pd.Period('2017-12')

characteristics = [
    'b_mkt',
    'b_smb',
    'b_hml'
] + ['const']
params = ['beta_ln_me'] + get_param_cols(characteristics)
dict_typecode = {
     0: 'Households',
     1: 'Banks',
     2: 'Insurance companies',
     3: 'Investment advisors',
     4: 'Mutual funds',
     5: 'Pension funds',
}

min_n_holding = 1000
n_quarters = 11
indexfund_id = 90457

# %%
df_result = main()
# Out:
# Imported s12
# Number of holdings:   30987
# Earliest date:   2014-06-30
# Latest date:   2017-12-31
#
# Imported s12type5
# Number of holdings:   572518
# Earliest date:   12/31/1994
# Latest date:   9/30/2022
#
# Imported s34
# Number of holdings:   22707709
# Earliest date:   2012-03-31
# Latest date:   2017-12-31
#
# Imported betas
# Number of dates:   432458
# Earliest date:   2012-01-31
# Latest date:   2017-12-29
#
# Imported security
# Number of holdings:   402452
# Earliest date:   2012-01-31
# Latest date:   2017-12-31
#
# Cleaned s12
# Number of holdings:   27327
# Earliest date:   2014-06
# Latest date:   2017-12
#
# Cleaned s12type5
# Number of firm/dates:   49372
# Earliest date:   2012-03
# Latest date:   2017-12
#
# Cleaned s34
# Number of holdings:   22267070
# Earliest date:   2012-03
# Latest date:   2017-12
#
# Cleaned beta
# Number of dates:   394535
# Earliest date:   2012-07
# Latest date:   2017-12
#
# Cleaned security
# Number of asset/dates:   348924
# Earliest date:   2012-07
# Latest date:   2017-12
# 2024-04-01 02:33:29,884 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# Merged s12 and s34
# Number of holdings:   22267070
# 2024-04-01 02:34:01,977 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:04,475 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:07,561 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:14,205 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:19,572 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:29,536 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:40,636 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:34:55,623 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:35:54,011 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:36:06,326 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:36:18,618 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:36:28,718 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:36:42,468 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:31,884 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:32,407 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:33,045 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:33,793 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:34,727 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:35,817 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:37,313 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:39,191 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-01 02:37:41,393 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# Constructed zero holdings
# Number of non-zero holdings:   22267070
# Number of zero holdings:   2478516
#
# Merged assets and factors
# Number of assets/dates:   118413
#
# Merged holdings and factors
# Number of investor/date/asset:   18074588
#
# Dropped unused investors/assets
# Number of holdings:   18029864
#
# Created household sector
# Number of holdings:   87361
#
# Created outside asset
# Number of outside holdings:   1096998
#
# Calculated investor AUM
# Number of investors:   5972
#
# Aggregated small investors
# Number of investors:   5163
#
# Binned investors
# Number of investors:   5163
# Number of bins:   111
#
# Created market equity instrument
# Number of valid instruments:   16362962
# Number of invalid instruments:   378
#
# Calculated holding weights
# Number of non-zero holdings:   14612714
# Number of zero holdings:   1750248
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 27
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 27
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 37
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.245197
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.243753
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.002351
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.266617
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.194447
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.167418
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.129447
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.119404
#          Iterations: 35
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.124892
#          Iterations: 35
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.169999
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.193544
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.271739
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.317982
#          Iterations: 37
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.281797
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.315366
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.004592
#          Iterations: 43
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.003189
#          Iterations: 44
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.002236
#          Iterations: 44
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.001821
#          Iterations: 42
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.000812
#          Iterations: 46
#          Function evaluations: 50
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: 0.000468
#          Iterations: 46
#          Function evaluations: 48
#          Gradient evaluations: 48
# Optimization terminated successfully.
#          Current function value: 0.000690
#          Iterations: 47
#          Function evaluations: 52
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 33
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 32
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.004788
#          Iterations: 52
#          Function evaluations: 57
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.081193
#          Iterations: 39
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 1.129943
#          Iterations: 34
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 1.458904
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.990722
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.585633
#          Iterations: 37
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.675156
#          Iterations: 43
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.808631
#          Iterations: 34
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.372654
#          Iterations: 37
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.403488
#          Iterations: 36
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.267924
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.889532
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.645016
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.477281
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.674132
#          Iterations: 37
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 2.116077
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.895983
#          Iterations: 37
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.882818
#          Iterations: 36
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.368671
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 65
#          Function evaluations: 73
#          Gradient evaluations: 73
# Optimization terminated successfully.
#          Current function value: 0.001387
#          Iterations: 49
#          Function evaluations: 55
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.000049
#          Iterations: 57
#          Function evaluations: 60
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.001688
#          Iterations: 52
#          Function evaluations: 54
#          Gradient evaluations: 54
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.005749
#          Iterations: 49
#          Function evaluations: 52
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: 0.004150
#          Iterations: 47
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 0.035608
#          Iterations: 43
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.072603
#          Iterations: 44
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.014223
#          Iterations: 49
#          Function evaluations: 52
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: 0.000034
#          Iterations: 58
#          Function evaluations: 63
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.002521
#          Iterations: 48
#          Function evaluations: 51
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: 0.001899
#          Iterations: 48
#          Function evaluations: 52
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: 0.000301
#          Iterations: 52
#          Function evaluations: 57
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.000637
#          Iterations: 50
#          Function evaluations: 53
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 33
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 32
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 29
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 27
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.015162
#          Iterations: 47
#          Function evaluations: 51
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: 0.014922
#          Iterations: 47
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 0.019595
#          Iterations: 44
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.026456
#          Iterations: 44
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 66
#          Function evaluations: 72
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 34
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.001213
#          Iterations: 53
#          Function evaluations: 59
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.011529
#          Iterations: 48
#          Function evaluations: 55
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: 0.010273
#          Iterations: 51
#          Function evaluations: 55
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: 0.005361
#          Iterations: 53
#          Function evaluations: 56
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: 0.024514
#          Iterations: 49
#          Function evaluations: 53
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: 0.003022
#          Iterations: 53
#          Function evaluations: 57
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.004366
#          Iterations: 53
#          Function evaluations: 57
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.002547
#          Iterations: 53
#          Function evaluations: 57
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.000262
#          Iterations: 57
#          Function evaluations: 63
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.001076
#          Iterations: 55
#          Function evaluations: 60
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 1.337394
#          Iterations: 34
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.965519
#          Iterations: 32
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.767505
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.641352
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 1.208843
#          Iterations: 32
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 1.620511
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.939352
#          Iterations: 32
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 1.217435
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 1.235852
#          Iterations: 32
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 1.011458
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 1.055547
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.781182
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.604629
#          Iterations: 32
#          Function evaluations: 34
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.984817
#          Iterations: 37
#          Function evaluations: 39
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 1.024089
#          Iterations: 34
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 1.133500
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.905238
#          Iterations: 34
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.662253
#          Iterations: 33
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.804490
#          Iterations: 32
#          Function evaluations: 35
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.654504
#          Iterations: 33
#          Function evaluations: 36
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.560341
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.695589
#          Iterations: 35
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.001845
#          Iterations: 46
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 25
# ...
# Optimization terminated successfully.
#          Current function value: 0.018487
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.077671
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.020216
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.015169
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015076
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.012811
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.079640
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.020794
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.032379
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.012582
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.011938
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.054135
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.013111
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.032162
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013115
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.011629
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.049080
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.028982
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.039570
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.012088
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.013934
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.070817
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.036621
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.025492
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.012366
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.012172
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.058550
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.043923
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022389
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.011072
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.010784
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.054076
#          Iterations: 25
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.045940
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.041815
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.013414
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.012913
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.064817
#          Iterations: 22
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.047393
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.003769
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.018525
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.015823
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.039611
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.060374
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.004589
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.021296
#          Iterations: 16
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.019432
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.055170
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.051624
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.002149
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.024128
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.019776
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.051113
#          Iterations: 26
#          Function evaluations: 31
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.012036
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.004415
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.021223
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.018425
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.046863
#          Iterations: 26
#          Function evaluations: 30
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.007643
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.001460
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.025131
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.016271
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.055836
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.010044
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.004592
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.026739
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.016987
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.052268
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012226
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.002846
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.029706
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.013585
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.052091
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.002209
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.001624
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.027471
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.014257
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.053590
#          Iterations: 25
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000621
#          Iterations: 17
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.006495
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.024904
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.013397
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.043297
#          Iterations: 24
#          Function evaluations: 28
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.005106
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.005788
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.023631
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.010912
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.021891
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.028334
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.034353
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.006300
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017698
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.010568
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
#
# Estimated parameters
# Number of converged estimations:   16362962
# Number of unconverged estimations:   0
#
# Calculated latent demand
# Number of investors:   5163

# %%
df_liquidity = calc_price_elasticity(df_result.loc[df_result['date'] == df_result['date'].median()])
# Out:
# 3239
# Added asset  0
# Added asset  1
# Added asset  2
# Added asset  3
# Added asset  4
# Added asset  5
# Added asset  6
# Added asset  7
# Added asset  8
# Added asset  9
# Added asset  10
# Added asset  11
# Added asset  12
# Added asset  13
# Added asset  14
# Added asset  15
# Added asset  16
# Added asset  17
# Added asset  18
# Added asset  19
# Added asset  20
# Added asset  21
# Added asset  22
# Added asset  23
# Added asset  24
# Added asset  25
# Added asset  26
# Added asset  27
# Added asset  28
# Added asset  29
# Added asset  30
# Added asset  31
# Added asset  32
# Added asset  33
# Added asset  34
# Added asset  35
# Added asset  36
# Added asset  37
# Added asset  38
# Added asset  39
# Added asset  40
# Added asset  41
# Added asset  42
# Added asset  43
# Added asset  44
# Added asset  45
# Added asset  46
# Added asset  47
# Added asset  48
# Added asset  49
# Added asset  50
# Added asset  51
# Added asset  52
# Added asset  53
# Added asset  54
# Added asset  55
# Added asset  56
# Added asset  57
# Added asset  58
# Added asset  59
# Added asset  60
# Added asset  61
# Added asset  62
# Added asset  63
# Added asset  64
# Added asset  65
# Added asset  66
# Added asset  67
# Added asset  68
# Added asset  69
# Added asset  70
# Added asset  71
# Added asset  72
# Added asset  73
# Added asset  74
# Added asset  75
# Added asset  76
# Added asset  77
# Added asset  78
# Added asset  79
# Added asset  80
# Added asset  81
# Added asset  82
# Added asset  83
# Added asset  84
# Added asset  85
# Added asset  86
# Added asset  87
# Added asset  88
# Added asset  89
# Added asset  90
# Added asset  91
# Added asset  92
# Added asset  93
# Added asset  94
# Added asset  95
# Added asset  96
# Added asset  97
# Added asset  98
# Added asset  99
# Added asset  100
# Added asset  101
# Added asset  102
# Added asset  103
# Added asset  104
# Added asset  105
# Added asset  106
# Added asset  107
# Added asset  108
# Added asset  109
# Added asset  110
# Added asset  111
# Added asset  112
# Added asset  113
# Added asset  114
# Added asset  115
# Added asset  116
# Added asset  117
# Added asset  118
# Added asset  119
# Added asset  120
# Added asset  121
# Added asset  122
# Added asset  123
# Added asset  124
# Added asset  125
# Added asset  126
# Added asset  127
# Added asset  128
# Added asset  129
# Added asset  130
# Added asset  131
# Added asset  132
# Added asset  133
# Added asset  134
# Added asset  135
# Added asset  136
# Added asset  137
# Added asset  138
# Added asset  139
# Added asset  140
# Added asset  141
# Added asset  142
# Added asset  143
# Added asset  144
# Added asset  145
# Added asset  146
# Added asset  147
# Added asset  148
# Added asset  149
# Added asset  150
# Added asset  151
# Added asset  152
# Added asset  153
# Added asset  154
# Added asset  155
# Added asset  156
# Added asset  157
# Added asset  158
# Added asset  159
# Added asset  160
# Added asset  161
# Added asset  162
# Added asset  163
# Added asset  164
# Added asset  165
# Added asset  166
# Added asset  167
# Added asset  168
# Added asset  169
# Added asset  170
# Added asset  171
# Added asset  172
# Added asset  173
# Added asset  174
# Added asset  175
# Added asset  176
# Added asset  177
# Added asset  178
# Added asset  179
# Added asset  180
# Added asset  181
# Added asset  182
# Added asset  183
# Added asset  184
# Added asset  185
# Added asset  186
# Added asset  187
# Added asset  188
# Added asset  189
# Added asset  190
# Added asset  191
# Added asset  192
# Added asset  193
# Added asset  194
# Added asset  195
# Added asset  196
# Added asset  197
# Added asset  198
# Added asset  199
# Added asset  200
# Added asset  201
# Added asset  202
# Added asset  203
# Added asset  204
# Added asset  205
# Added asset  206
# Added asset  207
# Added asset  208
# Added asset  209
# Added asset  210
# Added asset  211
# Added asset  212
# Added asset  213
# Added asset  214
# Added asset  215
# Added asset  216
# Added asset  217
# Added asset  218
# Added asset  219
# Added asset  220
# Added asset  221
# Added asset  222
# Added asset  223
# Added asset  224
# Added asset  225
# Added asset  226
# Added asset  227
# Added asset  228
# Added asset  229
# Added asset  230
# Added asset  231
# Added asset  232
# Added asset  233
# Added asset  234
# Added asset  235
# Added asset  236
# Added asset  237
# Added asset  238
# Added asset  239
# Added asset  240
# Added asset  241
# Added asset  242
# Added asset  243
# Added asset  244
# Added asset  245
# Added asset  246
# Added asset  247
# Added asset  248
# Added asset  249
# Added asset  250
# Added asset  251
# Added asset  252
# Added asset  253
# Added asset  254
# Added asset  255
# Added asset  256
# Added asset  257
# Added asset  258
# Added asset  259
# Added asset  260
# Added asset  261
# Added asset  262
# Added asset  263
# Added asset  264
# Added asset  265
# Added asset  266
# Added asset  267
# Added asset  268
# Added asset  269
# Added asset  270
# Added asset  271
# Added asset  272
# Added asset  273
# Added asset  274
# Added asset  275
# Added asset  276
# Added asset  277
# Added asset  278
# Added asset  279
# Added asset  280
# Added asset  281
# Added asset  282
# Added asset  283
# Added asset  284
# Added asset  285
# Added asset  286
# Added asset  287
# Added asset  288
# Added asset  289
# Added asset  290
# Added asset  291
# Added asset  292
# Added asset  293
# Added asset  294
# Added asset  295
# Added asset  296
# Added asset  297
# Added asset  298
# Added asset  299
# Added asset  300
# Added asset  301
# Added asset  302
# Added asset  303
# Added asset  304
# Added asset  305
# Added asset  306
# Added asset  307
# Added asset  308
# Added asset  309
# Added asset  310
# Added asset  311
# Added asset  312
# Added asset  313
# Added asset  314
# Added asset  315
# Added asset  316
# Added asset  317
# Added asset  318
# Added asset  319
# Added asset  320
# Added asset  321
# Added asset  322
# Added asset  323
# Added asset  324
# Added asset  325
# Added asset  326
# Added asset  327
# Added asset  328
# Added asset  329
# Added asset  330
# Added asset  331
# Added asset  332
# Added asset  333
# Added asset  334
# Added asset  335
# Added asset  336
# Added asset  337
# Added asset  338
# Added asset  339
# Added asset  340
# Added asset  341
# Added asset  342
# Added asset  343
# Added asset  344
# Added asset  345
# Added asset  346
# Added asset  347
# Added asset  348
# Added asset  349
# Added asset  350
# Added asset  351
# Added asset  352
# Added asset  353
# Added asset  354
# Added asset  355
# Added asset  356
# Added asset  357
# Added asset  358
# Added asset  359
# Added asset  360
# Added asset  361
# Added asset  362
# Added asset  363
# Added asset  364
# Added asset  365
# Added asset  366
# Added asset  367
# Added asset  368
# Added asset  369
# Added asset  370
# Added asset  371
# Added asset  372
# Added asset  373
# Added asset  374
# Added asset  375
# Added asset  376
# Added asset  377
# Added asset  378
# Added asset  379
# Added asset  380
# Added asset  381
# Added asset  382
# Added asset  383
# Added asset  384
# Added asset  385
# Added asset  386
# Added asset  387
# Added asset  388
# Added asset  389
# Added asset  390
# Added asset  391
# Added asset  392
# Added asset  393
# Added asset  394
# Added asset  395
# Added asset  396
# Added asset  397
# Added asset  398
# Added asset  399
# Added asset  400
# Added asset  401
# Added asset  402
# Added asset  403
# Added asset  404
# Added asset  405
# Added asset  406
# Added asset  407
# Added asset  408
# Added asset  409
# Added asset  410
# Added asset  411
# Added asset  412
# Added asset  413
# Added asset  414
# Added asset  415
# Added asset  416
# Added asset  417
# Added asset  418
# Added asset  419
# Added asset  420
# Added asset  421
# Added asset  422
# Added asset  423
# Added asset  424
# Added asset  425
# Added asset  426
# Added asset  427
# Added asset  428
# Added asset  429
# Added asset  430
# Added asset  431
# Added asset  432
# Added asset  433
# Added asset  434
# Added asset  435
# Added asset  436
# Added asset  437
# Added asset  438
# Added asset  439
# Added asset  440
# Added asset  441
# Added asset  442
# Added asset  443
# Added asset  444
# Added asset  445
# Added asset  446
# Added asset  447
# Added asset  448
# Added asset  449
# Added asset  450
# Added asset  451
# Added asset  452
# Added asset  453
# Added asset  454
# Added asset  455
# Added asset  456
# Added asset  457
# Added asset  458
# Added asset  459
# Added asset  460
# Added asset  461
# Added asset  462
# Added asset  463
# Added asset  464
# Added asset  465
# Added asset  466
# Added asset  467
# Added asset  468
# Added asset  469
# Added asset  470
# Added asset  471
# Added asset  472
# Added asset  473
# Added asset  474
# Added asset  475
# Added asset  476
# Added asset  477
# Added asset  478
# Added asset  479
# Added asset  480
# Added asset  481
# Added asset  482
# Added asset  483
# Added asset  484
# Added asset  485
# Added asset  486
# Added asset  487
# Added asset  488
# Added asset  489
# Added asset  490
# Added asset  491
# Added asset  492
# Added asset  493
# Added asset  494
# Added asset  495
# Added asset  496
# Added asset  497
# Added asset  498
# Added asset  499
# Added asset  500
# Added asset  501
# Added asset  502
# Added asset  503
# Added asset  504
# Added asset  505
# Added asset  506
# Added asset  507
# Added asset  508
# Added asset  509
# Added asset  510
# Added asset  511
# Added asset  512
# Added asset  513
# Added asset  514
# Added asset  515
# Added asset  516
# Added asset  517
# Added asset  518
# Added asset  519
# Added asset  520
# Added asset  521
# Added asset  522
# Added asset  523
# Added asset  524
# Added asset  525
# Added asset  526
# Added asset  527
# Added asset  528
# Added asset  529
# Added asset  530
# Added asset  531
# Added asset  532
# Added asset  533
# Added asset  534
# Added asset  535
# Added asset  536
# Added asset  537
# Added asset  538
# Added asset  539
# Added asset  540
# Added asset  541
# Added asset  542
# Added asset  543
# Added asset  544
# Added asset  545
# Added asset  546
# Added asset  547
# Added asset  548
# Added asset  549
# Added asset  550
# Added asset  551
# Added asset  552
# Added asset  553
# Added asset  554
# Added asset  555
# Added asset  556
# Added asset  557
# Added asset  558
# Added asset  559
# Added asset  560
# Added asset  561
# Added asset  562
# Added asset  563
# Added asset  564
# Added asset  565
# Added asset  566
# Added asset  567
# Added asset  568
# Added asset  569
# Added asset  570
# Added asset  571
# Added asset  572
# Added asset  573
# Added asset  574
# Added asset  575
# Added asset  576
# Added asset  577
# Added asset  578
# Added asset  579
# Added asset  580
# Added asset  581
# Added asset  582
# Added asset  583
# Added asset  584
# Added asset  585
# Added asset  586
# Added asset  587
# Added asset  588
# Added asset  589
# Added asset  590
# Added asset  591
# Added asset  592
# Added asset  593
# Added asset  594
# Added asset  595
# Added asset  596
# Added asset  597
# Added asset  598
# Added asset  599
# Added asset  600
# Added asset  601
# Added asset  602
# Added asset  603
# Added asset  604
# Added asset  605
# Added asset  606
# Added asset  607
# Added asset  608
# Added asset  609
# Added asset  610
# Added asset  611
# Added asset  612
# Added asset  613
# Added asset  614
# Added asset  615
# Added asset  616
# Added asset  617
# Added asset  618
# Added asset  619
# Added asset  620
# Added asset  621
# Added asset  622
# Added asset  623
# Added asset  624
# Added asset  625
# Added asset  626
# Added asset  627
# Added asset  628
# Added asset  629
# Added asset  630
# Added asset  631
# Added asset  632
# Added asset  633
# Added asset  634
# Added asset  635
# Added asset  636
# Added asset  637
# Added asset  638
# Added asset  639
# Added asset  640
# Added asset  641
# Added asset  642
# Added asset  643
# Added asset  644
# Added asset  645
# Added asset  646
# Added asset  647
# Added asset  648
# Added asset  649
# Added asset  650
# Added asset  651
# Added asset  652
# Added asset  653
# Added asset  654
# Added asset  655
# Added asset  656
# Added asset  657
# Added asset  658
# Added asset  659
# Added asset  660
# Added asset  661
# Added asset  662
# Added asset  663
# Added asset  664
# Added asset  665
# Added asset  666
# Added asset  667
# Added asset  668
# Added asset  669
# Added asset  670
# Added asset  671
# Added asset  672
# Added asset  673
# Added asset  674
# Added asset  675
# Added asset  676
# Added asset  677
# Added asset  678
# Added asset  679
# Added asset  680
# Added asset  681
# Added asset  682
# Added asset  683
# Added asset  684
# Added asset  685
# Added asset  686
# Added asset  687
# Added asset  688
# Added asset  689
# Added asset  690
# Added asset  691
# Added asset  692
# Added asset  693
# Added asset  694
# Added asset  695
# Added asset  696
# Added asset  697
# Added asset  698
# Added asset  699
# Added asset  700
# Added asset  701
# Added asset  702
# Added asset  703
# Added asset  704
# Added asset  705
# Added asset  706
# Added asset  707
# Added asset  708
# Added asset  709
# Added asset  710
# Added asset  711
# Added asset  712
# Added asset  713
# Added asset  714
# Added asset  715
# Added asset  716
# Added asset  717
# Added asset  718
# Added asset  719
# Added asset  720
# Added asset  721
# Added asset  722
# Added asset  723
# Added asset  724
# Added asset  725
# Added asset  726
# Added asset  727
# Added asset  728
# Added asset  729
# Added asset  730
# Added asset  731
# Added asset  732
# Added asset  733
# Added asset  734
# Added asset  735
# Added asset  736
# Added asset  737
# Added asset  738
# Added asset  739
# Added asset  740
# Added asset  741
# Added asset  742
# Added asset  743
# Added asset  744
# Added asset  745
# Added asset  746
# Added asset  747
# Added asset  748
# Added asset  749
# Added asset  750
# Added asset  751
# Added asset  752
# Added asset  753
# Added asset  754
# Added asset  755
# Added asset  756
# Added asset  757
# Added asset  758
# Added asset  759
# Added asset  760
# Added asset  761
# Added asset  762
# Added asset  763
# Added asset  764
# Added asset  765
# Added asset  766
# Added asset  767
# Added asset  768
# Added asset  769
# Added asset  770
# Added asset  771
# Added asset  772
# Added asset  773
# Added asset  774
# Added asset  775
# Added asset  776
# Added asset  777
# Added asset  778
# Added asset  779
# Added asset  780
# Added asset  781
# Added asset  782
# Added asset  783
# Added asset  784
# Added asset  785
# Added asset  786
# Added asset  787
# Added asset  788
# Added asset  789
# Added asset  790
# Added asset  791
# Added asset  792
# Added asset  793
# Added asset  794
# Added asset  795
# Added asset  796
# Added asset  797
# Added asset  798
# Added asset  799
# Added asset  800
# Added asset  801
# Added asset  802
# Added asset  803
# Added asset  804
# Added asset  805
# Added asset  806
# Added asset  807
# Added asset  808
# Added asset  809
# Added asset  810
# Added asset  811
# Added asset  812
# Added asset  813
# Added asset  814
# Added asset  815
# Added asset  816
# Added asset  817
# Added asset  818
# Added asset  819
# Added asset  820
# Added asset  821
# Added asset  822
# Added asset  823
# Added asset  824
# Added asset  825
# Added asset  826
# Added asset  827
# Added asset  828
# Added asset  829
# Added asset  830
# Added asset  831
# Added asset  832
# Added asset  833
# Added asset  834
# Added asset  835
# Added asset  836
# Added asset  837
# Added asset  838
# Added asset  839
# Added asset  840
# Added asset  841
# Added asset  842
# Added asset  843
# Added asset  844
# Added asset  845
# Added asset  846
# Added asset  847
# Added asset  848
# Added asset  849
# Added asset  850
# Added asset  851
# Added asset  852
# Added asset  853
# Added asset  854
# Added asset  855
# Added asset  856
# Added asset  857
# Added asset  858
# Added asset  859
# Added asset  860
# Added asset  861
# Added asset  862
# Added asset  863
# Added asset  864
# Added asset  865
# Added asset  866
# Added asset  867
# Added asset  868
# Added asset  869
# Added asset  870
# Added asset  871
# Added asset  872
# Added asset  873
# Added asset  874
# Added asset  875
# Added asset  876
# Added asset  877
# Added asset  878
# Added asset  879
# Added asset  880
# Added asset  881
# Added asset  882
# Added asset  883
# Added asset  884
# Added asset  885
# Added asset  886
# Added asset  887
# Added asset  888
# Added asset  889
# Added asset  890
# Added asset  891
# Added asset  892
# Added asset  893
# Added asset  894
# Added asset  895
# Added asset  896
# Added asset  897
# Added asset  898
# Added asset  899
# Added asset  900
# Added asset  901
# Added asset  902
# Added asset  903
# Added asset  904
# Added asset  905
# Added asset  906
# Added asset  907
# Added asset  908
# Added asset  909
# Added asset  910
# Added asset  911
# Added asset  912
# Added asset  913
# Added asset  914
# Added asset  915
# Added asset  916
# Added asset  917
# Added asset  918
# Added asset  919
# Added asset  920
# Added asset  921
# Added asset  922
# Added asset  923
# Added asset  924
# Added asset  925
# Added asset  926
# Added asset  927
# Added asset  928
# Added asset  929
# Added asset  930
# Added asset  931
# Added asset  932
# Added asset  933
# Added asset  934
# Added asset  935
# Added asset  936
# Added asset  937
# Added asset  938
# Added asset  939
# Added asset  940
# Added asset  941
# Added asset  942
# Added asset  943
# Added asset  944
# Added asset  945
# Added asset  946
# Added asset  947
# Added asset  948
# Added asset  949
# Added asset  950
# Added asset  951
# Added asset  952
# Added asset  953
# Added asset  954
# Added asset  955
# Added asset  956
# Added asset  957
# Added asset  958
# Added asset  959
# Added asset  960
# Added asset  961
# Added asset  962
# Added asset  963
# Added asset  964
# Added asset  965
# Added asset  966
# Added asset  967
# Added asset  968
# Added asset  969
# Added asset  970
# Added asset  971
# Added asset  972
# Added asset  973
# Added asset  974
# Added asset  975
# Added asset  976
# Added asset  977
# Added asset  978
# Added asset  979
# Added asset  980
# Added asset  981
# Added asset  982
# Added asset  983
# Added asset  984
# Added asset  985
# Added asset  986
# Added asset  987
# Added asset  988
# Added asset  989
# Added asset  990
# Added asset  991
# Added asset  992
# Added asset  993
# Added asset  994
# Added asset  995
# Added asset  996
# Added asset  997
# Added asset  998
# Added asset  999
# Added asset  1000
# Added asset  1001
# Added asset  1002
# Added asset  1003
# Added asset  1004
# Added asset  1005
# Added asset  1006
# Added asset  1007
# Added asset  1008
# Added asset  1009
# Added asset  1010
# Added asset  1011
# Added asset  1012
# Added asset  1013
# Added asset  1014
# Added asset  1015
# Added asset  1016
# Added asset  1017
# Added asset  1018
# Added asset  1019
# Added asset  1020
# Added asset  1021
# Added asset  1022
# Added asset  1023
# Added asset  1024
# Added asset  1025
# Added asset  1026
# Added asset  1027
# Added asset  1028
# Added asset  1029
# Added asset  1030
# Added asset  1031
# Added asset  1032
# Added asset  1033
# Added asset  1034
# Added asset  1035
# Added asset  1036
# Added asset  1037
# Added asset  1038
# Added asset  1039
# Added asset  1040
# Added asset  1041
# Added asset  1042
# Added asset  1043
# Added asset  1044
# Added asset  1045
# Added asset  1046
# Added asset  1047
# Added asset  1048
# Added asset  1049
# Added asset  1050
# Added asset  1051
# Added asset  1052
# Added asset  1053
# Added asset  1054
# Added asset  1055
# Added asset  1056
# Added asset  1057
# Added asset  1058
# Added asset  1059
# Added asset  1060
# Added asset  1061
# Added asset  1062
# Added asset  1063
# Added asset  1064
# Added asset  1065
# Added asset  1066
# Added asset  1067
# Added asset  1068
# Added asset  1069
# Added asset  1070
# Added asset  1071
# Added asset  1072
# Added asset  1073
# Added asset  1074
# Added asset  1075
# Added asset  1076
# Added asset  1077
# Added asset  1078
# Added asset  1079
# Added asset  1080
# Added asset  1081
# Added asset  1082
# Added asset  1083
# Added asset  1084
# Added asset  1085
# Added asset  1086
# Added asset  1087
# Added asset  1088
# Added asset  1089
# Added asset  1090
# Added asset  1091
# Added asset  1092
# Added asset  1093
# Added asset  1094
# Added asset  1095
# Added asset  1096
# Added asset  1097
# Added asset  1098
# Added asset  1099
# Added asset  1100
# Added asset  1101
# Added asset  1102
# Added asset  1103
# Added asset  1104
# Added asset  1105
# Added asset  1106
# Added asset  1107
# Added asset  1108
# Added asset  1109
# Added asset  1110
# Added asset  1111
# Added asset  1112
# Added asset  1113
# Added asset  1114
# Added asset  1115
# Added asset  1116
# Added asset  1117
# Added asset  1118
# Added asset  1119
# Added asset  1120
# Added asset  1121
# Added asset  1122
# Added asset  1123
# Added asset  1124
# Added asset  1125
# Added asset  1126
# Added asset  1127
# Added asset  1128
# Added asset  1129
# Added asset  1130
# Added asset  1131
# Added asset  1132
# Added asset  1133
# Added asset  1134
# Added asset  1135
# Added asset  1136
# Added asset  1137
# Added asset  1138
# Added asset  1139
# Added asset  1140
# Added asset  1141
# Added asset  1142
# Added asset  1143
# Added asset  1144
# Added asset  1145
# Added asset  1146
# Added asset  1147
# Added asset  1148
# Added asset  1149
# Added asset  1150
# Added asset  1151
# Added asset  1152
# Added asset  1153
# Added asset  1154
# Added asset  1155
# Added asset  1156
# Added asset  1157
# Added asset  1158
# Added asset  1159
# Added asset  1160
# Added asset  1161
# Added asset  1162
# Added asset  1163
# Added asset  1164
# Added asset  1165
# Added asset  1166
# Added asset  1167
# Added asset  1168
# Added asset  1169
# Added asset  1170
# Added asset  1171
# Added asset  1172
# Added asset  1173
# Added asset  1174
# Added asset  1175
# Added asset  1176
# Added asset  1177
# Added asset  1178
# Added asset  1179
# Added asset  1180
# Added asset  1181
# Added asset  1182
# Added asset  1183
# Added asset  1184
# Added asset  1185
# Added asset  1186
# Added asset  1187
# Added asset  1188
# Added asset  1189
# Added asset  1190
# Added asset  1191
# Added asset  1192
# Added asset  1193
# Added asset  1194
# Added asset  1195
# Added asset  1196
# Added asset  1197
# Added asset  1198
# Added asset  1199
# Added asset  1200
# Added asset  1201
# Added asset  1202
# Added asset  1203
# Added asset  1204
# Added asset  1205
# Added asset  1206
# Added asset  1207
# Added asset  1208
# Added asset  1209
# Added asset  1210
# Added asset  1211
# Added asset  1212
# Added asset  1213
# Added asset  1214
# Added asset  1215
# Added asset  1216
# Added asset  1217
# Added asset  1218
# Added asset  1219
# Added asset  1220
# Added asset  1221
# Added asset  1222
# Added asset  1223
# Added asset  1224
# Added asset  1225
# Added asset  1226
# Added asset  1227
# Added asset  1228
# Added asset  1229
# Added asset  1230
# Added asset  1231
# Added asset  1232
# Added asset  1233
# Added asset  1234
# Added asset  1235
# Added asset  1236
# Added asset  1237
# Added asset  1238
# Added asset  1239
# Added asset  1240
# Added asset  1241
# Added asset  1242
# Added asset  1243
# Added asset  1244
# Added asset  1245
# Added asset  1246
# Added asset  1247
# Added asset  1248
# Added asset  1249
# Added asset  1250
# Added asset  1251
# Added asset  1252
# Added asset  1253
# Added asset  1254
# Added asset  1255
# Added asset  1256
# Added asset  1257
# Added asset  1258
# Added asset  1259
# Added asset  1260
# Added asset  1261
# Added asset  1262
# Added asset  1263
# Added asset  1264
# Added asset  1265
# Added asset  1266
# Added asset  1267
# Added asset  1268
# Added asset  1269
# Added asset  1270
# Added asset  1271
# Added asset  1272
# Added asset  1273
# Added asset  1274
# Added asset  1275
# Added asset  1276
# Added asset  1277
# Added asset  1278
# Added asset  1279
# Added asset  1280
# Added asset  1281
# Added asset  1282
# Added asset  1283
# Added asset  1284
# Added asset  1285
# Added asset  1286
# Added asset  1287
# Added asset  1288
# Added asset  1289
# Added asset  1290
# Added asset  1291
# Added asset  1292
# Added asset  1293
# Added asset  1294
# Added asset  1295
# Added asset  1296
# Added asset  1297
# Added asset  1298
# Added asset  1299
# Added asset  1300
# Added asset  1301
# Added asset  1302
# Added asset  1303
# Added asset  1304
# Added asset  1305
# Added asset  1306
# Added asset  1307
# Added asset  1308
# Added asset  1309
# Added asset  1310
# Added asset  1311
# Added asset  1312
# Added asset  1313
# Added asset  1314
# Added asset  1315
# Added asset  1316
# Added asset  1317
# Added asset  1318
# Added asset  1319
# Added asset  1320
# Added asset  1321
# Added asset  1322
# Added asset  1323
# Added asset  1324
# Added asset  1325
# Added asset  1326
# Added asset  1327
# Added asset  1328
# Added asset  1329
# Added asset  1330
# Added asset  1331
# Added asset  1332
# Added asset  1333
# Added asset  1334
# Added asset  1335
# Added asset  1336
# Added asset  1337
# Added asset  1338
# Added asset  1339
# Added asset  1340
# Added asset  1341
# Added asset  1342
# Added asset  1343
# Added asset  1344
# Added asset  1345
# Added asset  1346
# Added asset  1347
# Added asset  1348
# Added asset  1349
# Added asset  1350
# Added asset  1351
# Added asset  1352
# Added asset  1353
# Added asset  1354
# Added asset  1355
# Added asset  1356
# Added asset  1357
# Added asset  1358
# Added asset  1359
# Added asset  1360
# Added asset  1361
# Added asset  1362
# Added asset  1363
# Added asset  1364
# Added asset  1365
# Added asset  1366
# Added asset  1367
# Added asset  1368
# Added asset  1369
# Added asset  1370
# Added asset  1371
# Added asset  1372
# Added asset  1373
# Added asset  1374
# Added asset  1375
# Added asset  1376
# Added asset  1377
# Added asset  1378
# Added asset  1379
# Added asset  1380
# Added asset  1381
# Added asset  1382
# Added asset  1383
# Added asset  1384
# Added asset  1385
# Added asset  1386
# Added asset  1387
# Added asset  1388
# Added asset  1389
# Added asset  1390
# Added asset  1391
# Added asset  1392
# Added asset  1393
# Added asset  1394
# Added asset  1395
# Added asset  1396
# Added asset  1397
# Added asset  1398
# Added asset  1399
# Added asset  1400
# Added asset  1401
# Added asset  1402
# Added asset  1403
# Added asset  1404
# Added asset  1405
# Added asset  1406
# Added asset  1407
# Added asset  1408
# Added asset  1409
# Added asset  1410
# Added asset  1411
# Added asset  1412
# Added asset  1413
# Added asset  1414
# Added asset  1415
# Added asset  1416
# Added asset  1417
# Added asset  1418
# Added asset  1419
# Added asset  1420
# Added asset  1421
# Added asset  1422
# Added asset  1423
# Added asset  1424
# Added asset  1425
# Added asset  1426
# Added asset  1427
# Added asset  1428
# Added asset  1429
# Added asset  1430
# Added asset  1431
# Added asset  1432
# Added asset  1433
# Added asset  1434
# Added asset  1435
# Added asset  1436
# Added asset  1437
# Added asset  1438
# Added asset  1439
# Added asset  1440
# Added asset  1441
# Added asset  1442
# Added asset  1443
# Added asset  1444
# Added asset  1445
# Added asset  1446
# Added asset  1447
# Added asset  1448
# Added asset  1449
# Added asset  1450
# Added asset  1451
# Added asset  1452
# Added asset  1453
# Added asset  1454
# Added asset  1455
# Added asset  1456
# Added asset  1457
# Added asset  1458
# Added asset  1459
# Added asset  1460
# Added asset  1461
# Added asset  1462
# Added asset  1463
# Added asset  1464
# Added asset  1465
# Added asset  1466
# Added asset  1467
# Added asset  1468
# Added asset  1469
# Added asset  1470
# Added asset  1471
# Added asset  1472
# Added asset  1473
# Added asset  1474
# Added asset  1475
# Added asset  1476
# Added asset  1477
# Added asset  1478
# Added asset  1479
# Added asset  1480
# Added asset  1481
# Added asset  1482
# Added asset  1483
# Added asset  1484
# Added asset  1485
# Added asset  1486
# Added asset  1487
# Added asset  1488
# Added asset  1489
# Added asset  1490
# Added asset  1491
# Added asset  1492
# Added asset  1493
# Added asset  1494
# Added asset  1495
# Added asset  1496
# Added asset  1497
# Added asset  1498
# Added asset  1499
# Added asset  1500
# Added asset  1501
# Added asset  1502
# Added asset  1503
# Added asset  1504
# Added asset  1505
# Added asset  1506
# Added asset  1507
# Added asset  1508
# Added asset  1509
# Added asset  1510
# Added asset  1511
# Added asset  1512
# Added asset  1513
# Added asset  1514
# Added asset  1515
# Added asset  1516
# Added asset  1517
# Added asset  1518
# Added asset  1519
# Added asset  1520
# Added asset  1521
# Added asset  1522
# Added asset  1523
# Added asset  1524
# Added asset  1525
# Added asset  1526
# Added asset  1527
# Added asset  1528
# Added asset  1529
# Added asset  1530
# Added asset  1531
# Added asset  1532
# Added asset  1533
# Added asset  1534
# Added asset  1535
# Added asset  1536
# Added asset  1537
# Added asset  1538
# Added asset  1539
# Added asset  1540
# Added asset  1541
# Added asset  1542
# Added asset  1543
# Added asset  1544
# Added asset  1545
# Added asset  1546
# Added asset  1547
# Added asset  1548
# Added asset  1549
# Added asset  1550
# Added asset  1551
# Added asset  1552
# Added asset  1553
# Added asset  1554
# Added asset  1555
# Added asset  1556
# Added asset  1557
# Added asset  1558
# Added asset  1559
# Added asset  1560
# Added asset  1561
# Added asset  1562
# Added asset  1563
# Added asset  1564
# Added asset  1565
# Added asset  1566
# Added asset  1567
# Added asset  1568
# Added asset  1569
# Added asset  1570
# Added asset  1571
# Added asset  1572
# Added asset  1573
# Added asset  1574
# Added asset  1575
# Added asset  1576
# Added asset  1577
# Added asset  1578
# Added asset  1579
# Added asset  1580
# Added asset  1581
# Added asset  1582
# Added asset  1583
# Added asset  1584
# Added asset  1585
# Added asset  1586
# Added asset  1587
# Added asset  1588
# Added asset  1589
# Added asset  1590
# Added asset  1591
# Added asset  1592
# Added asset  1593
# Added asset  1594
# Added asset  1595
# Added asset  1596
# Added asset  1597
# Added asset  1598
# Added asset  1599
# Added asset  1600
# Added asset  1601
# Added asset  1602
# Added asset  1603
# Added asset  1604
# Added asset  1605
# Added asset  1606
# Added asset  1607
# Added asset  1608
# Added asset  1609
# Added asset  1610
# Added asset  1611
# Added asset  1612
# Added asset  1613
# Added asset  1614
# Added asset  1615
# Added asset  1616
# Added asset  1617
# Added asset  1618
# Added asset  1619
# Added asset  1620
# Added asset  1621
# Added asset  1622
# Added asset  1623
# Added asset  1624
# Added asset  1625
# Added asset  1626
# Added asset  1627
# Added asset  1628
# Added asset  1629
# Added asset  1630
# Added asset  1631
# Added asset  1632
# Added asset  1633
# Added asset  1634
# Added asset  1635
# Added asset  1636
# Added asset  1637
# Added asset  1638
# Added asset  1639
# Added asset  1640
# Added asset  1641
# Added asset  1642
# Added asset  1643
# Added asset  1644
# Added asset  1645
# Added asset  1646
# Added asset  1647
# Added asset  1648
# Added asset  1649
# Added asset  1650
# Added asset  1651
# Added asset  1652
# Added asset  1653
# Added asset  1654
# Added asset  1655
# Added asset  1656
# Added asset  1657
# Added asset  1658
# Added asset  1659
# Added asset  1660
# Added asset  1661
# Added asset  1662
# Added asset  1663
# Added asset  1664
# Added asset  1665
# Added asset  1666
# Added asset  1667
# Added asset  1668
# Added asset  1669
# Added asset  1670
# Added asset  1671
# Added asset  1672
# Added asset  1673
# Added asset  1674
# Added asset  1675
# Added asset  1676
# Added asset  1677
# Added asset  1678
# Added asset  1679
# Added asset  1680
# Added asset  1681
# Added asset  1682
# Added asset  1683
# Added asset  1684
# Added asset  1685
# Added asset  1686
# Added asset  1687
# Added asset  1688
# Added asset  1689
# Added asset  1690
# Added asset  1691
# Added asset  1692
# Added asset  1693
# Added asset  1694
# Added asset  1695
# Added asset  1696
# Added asset  1697
# Added asset  1698
# Added asset  1699
# Added asset  1700
# Added asset  1701
# Added asset  1702
# Added asset  1703
# Added asset  1704
# Added asset  1705
# Added asset  1706
# Added asset  1707
# Added asset  1708
# Added asset  1709
# Added asset  1710
# Added asset  1711
# Added asset  1712
# Added asset  1713
# Added asset  1714
# Added asset  1715
# Added asset  1716
# Added asset  1717
# Added asset  1718
# Added asset  1719
# Added asset  1720
# Added asset  1721
# Added asset  1722
# Added asset  1723
# Added asset  1724
# Added asset  1725
# Added asset  1726
# Added asset  1727
# Added asset  1728
# Added asset  1729
# Added asset  1730
# Added asset  1731
# Added asset  1732
# Added asset  1733
# Added asset  1734
# Added asset  1735
# Added asset  1736
# Added asset  1737
# Added asset  1738
# Added asset  1739
# Added asset  1740
# Added asset  1741
# Added asset  1742
# Added asset  1743
# Added asset  1744
# Added asset  1745
# Added asset  1746
# Added asset  1747
# Added asset  1748
# Added asset  1749
# Added asset  1750
# Added asset  1751
# Added asset  1752
# Added asset  1753
# Added asset  1754
# Added asset  1755
# Added asset  1756
# Added asset  1757
# Added asset  1758
# Added asset  1759
# Added asset  1760
# Added asset  1761
# Added asset  1762
# Added asset  1763
# Added asset  1764
# Added asset  1765
# Added asset  1766
# Added asset  1767
# Added asset  1768
# Added asset  1769
# Added asset  1770
# Added asset  1771
# Added asset  1772
# Added asset  1773
# Added asset  1774
# Added asset  1775
# Added asset  1776
# Added asset  1777
# Added asset  1778
# Added asset  1779
# Added asset  1780
# Added asset  1781
# Added asset  1782
# Added asset  1783
# Added asset  1784
# Added asset  1785
# Added asset  1786
# Added asset  1787
# Added asset  1788
# Added asset  1789
# Added asset  1790
# Added asset  1791
# Added asset  1792
# Added asset  1793
# Added asset  1794
# Added asset  1795
# Added asset  1796
# Added asset  1797
# Added asset  1798
# Added asset  1799
# Added asset  1800
# Added asset  1801
# Added asset  1802
# Added asset  1803
# Added asset  1804
# Added asset  1805
# Added asset  1806
# Added asset  1807
# Added asset  1808
# Added asset  1809
# Added asset  1810
# Added asset  1811
# Added asset  1812
# Added asset  1813
# Added asset  1814
# Added asset  1815
# Added asset  1816
# Added asset  1817
# Added asset  1818
# Added asset  1819
# Added asset  1820
# Added asset  1821
# Added asset  1822
# Added asset  1823
# Added asset  1824
# Added asset  1825
# Added asset  1826
# Added asset  1827
# Added asset  1828
# Added asset  1829
# Added asset  1830
# Added asset  1831
# Added asset  1832
# Added asset  1833
# Added asset  1834
# Added asset  1835
# Added asset  1836
# Added asset  1837
# Added asset  1838
# Added asset  1839
# Added asset  1840
# Added asset  1841
# Added asset  1842
# Added asset  1843
# Added asset  1844
# Added asset  1845
# Added asset  1846
# Added asset  1847
# Added asset  1848
# Added asset  1849
# Added asset  1850
# Added asset  1851
# Added asset  1852
# Added asset  1853
# Added asset  1854
# Added asset  1855
# Added asset  1856
# Added asset  1857
# Added asset  1858
# Added asset  1859
# Added asset  1860
# Added asset  1861
# Added asset  1862
# Added asset  1863
# Added asset  1864
# Added asset  1865
# Added asset  1866
# Added asset  1867
# Added asset  1868
# Added asset  1869
# Added asset  1870
# Added asset  1871
# Added asset  1872
# Added asset  1873
# Added asset  1874
# Added asset  1875
# Added asset  1876
# Added asset  1877
# Added asset  1878
# Added asset  1879
# Added asset  1880
# Added asset  1881
# Added asset  1882
# Added asset  1883
# Added asset  1884
# Added asset  1885
# Added asset  1886
# Added asset  1887
# Added asset  1888
# Added asset  1889
# Added asset  1890
# Added asset  1891
# Added asset  1892
# Added asset  1893
# Added asset  1894
# Added asset  1895
# Added asset  1896
# Added asset  1897
# Added asset  1898
# Added asset  1899
# Added asset  1900
# Added asset  1901
# Added asset  1902
# Added asset  1903
# Added asset  1904
# Added asset  1905
# Added asset  1906
# Added asset  1907
# Added asset  1908
# Added asset  1909
# Added asset  1910
# Added asset  1911
# Added asset  1912
# Added asset  1913
# Added asset  1914
# Added asset  1915
# Added asset  1916
# Added asset  1917
# Added asset  1918
# Added asset  1919
# Added asset  1920
# Added asset  1921
# Added asset  1922
# Added asset  1923
# Added asset  1924
# Added asset  1925
# Added asset  1926
# Added asset  1927
# Added asset  1928
# Added asset  1929
# Added asset  1930
# Added asset  1931
# Added asset  1932
# Added asset  1933
# Added asset  1934
# Added asset  1935
# Added asset  1936
# Added asset  1937
# Added asset  1938
# Added asset  1939
# Added asset  1940
# Added asset  1941
# Added asset  1942
# Added asset  1943
# Added asset  1944
# Added asset  1945
# Added asset  1946
# Added asset  1947
# Added asset  1948
# Added asset  1949
# Added asset  1950
# Added asset  1951
# Added asset  1952
# Added asset  1953
# Added asset  1954
# Added asset  1955
# Added asset  1956
# Added asset  1957
# Added asset  1958
# Added asset  1959
# Added asset  1960
# Added asset  1961
# Added asset  1962
# Added asset  1963
# Added asset  1964
# Added asset  1965
# Added asset  1966
# Added asset  1967
# Added asset  1968
# Added asset  1969
# Added asset  1970
# Added asset  1971
# Added asset  1972
# Added asset  1973
# Added asset  1974
# Added asset  1975
# Added asset  1976
# Added asset  1977
# Added asset  1978
# Added asset  1979
# Added asset  1980
# Added asset  1981
# Added asset  1982
# Added asset  1983
# Added asset  1984
# Added asset  1985
# Added asset  1986
# Added asset  1987
# Added asset  1988
# Added asset  1989
# Added asset  1990
# Added asset  1991
# Added asset  1992
# Added asset  1993
# Added asset  1994
# Added asset  1995
# Added asset  1996
# Added asset  1997
# Added asset  1998
# Added asset  1999
# Added asset  2000
# Added asset  2001
# Added asset  2002
# Added asset  2003
# Added asset  2004
# Added asset  2005
# Added asset  2006
# Added asset  2007
# Added asset  2008
# Added asset  2009
# Added asset  2010
# Added asset  2011
# Added asset  2012
# Added asset  2013
# Added asset  2014
# Added asset  2015
# Added asset  2016
# Added asset  2017
# Added asset  2018
# Added asset  2019
# Added asset  2020
# Added asset  2021
# Added asset  2022
# Added asset  2023
# Added asset  2024
# Added asset  2025
# Added asset  2026
# Added asset  2027
# Added asset  2028
# Added asset  2029
# Added asset  2030
# Added asset  2031
# Added asset  2032
# Added asset  2033
# Added asset  2034
# Added asset  2035
# Added asset  2036
# Added asset  2037
# Added asset  2038
# Added asset  2039
# Added asset  2040
# Added asset  2041
# Added asset  2042
# Added asset  2043
# Added asset  2044
# Added asset  2045
# Added asset  2046
# Added asset  2047
# Added asset  2048
# Added asset  2049
# Added asset  2050
# Added asset  2051
# Added asset  2052
# Added asset  2053
# Added asset  2054
# Added asset  2055
# Added asset  2056
# Added asset  2057
# Added asset  2058
# Added asset  2059
# Added asset  2060
# Added asset  2061
# Added asset  2062
# Added asset  2063
# Added asset  2064
# Added asset  2065
# Added asset  2066
# Added asset  2067
# Added asset  2068
# Added asset  2069
# Added asset  2070
# Added asset  2071
# Added asset  2072
# Added asset  2073
# Added asset  2074
# Added asset  2075
# Added asset  2076
# Added asset  2077
# Added asset  2078
# Added asset  2079
# Added asset  2080
# Added asset  2081
# Added asset  2082
# Added asset  2083
# Added asset  2084
# Added asset  2085
# Added asset  2086
# Added asset  2087
# Added asset  2088
# Added asset  2089
# Added asset  2090
# Added asset  2091
# Added asset  2092
# Added asset  2093
# Added asset  2094
# Added asset  2095
# Added asset  2096
# Added asset  2097
# Added asset  2098
# Added asset  2099
# Added asset  2100
# Added asset  2101
# Added asset  2102
# Added asset  2103
# Added asset  2104
# Added asset  2105
# Added asset  2106
# Added asset  2107
# Added asset  2108
# Added asset  2109
# Added asset  2110
# Added asset  2111
# Added asset  2112
# Added asset  2113
# Added asset  2114
# Added asset  2115
# Added asset  2116
# Added asset  2117
# Added asset  2118
# Added asset  2119
# Added asset  2120
# Added asset  2121
# Added asset  2122
# Added asset  2123
# Added asset  2124
# Added asset  2125
# Added asset  2126
# Added asset  2127
# Added asset  2128
# Added asset  2129
# Added asset  2130
# Added asset  2131
# Added asset  2132
# Added asset  2133
# Added asset  2134
# Added asset  2135
# Added asset  2136
# Added asset  2137
# Added asset  2138
# Added asset  2139
# Added asset  2140
# Added asset  2141
# Added asset  2142
# Added asset  2143
# Added asset  2144
# Added asset  2145
# Added asset  2146
# Added asset  2147
# Added asset  2148
# Added asset  2149
# Added asset  2150
# Added asset  2151
# Added asset  2152
# Added asset  2153
# Added asset  2154
# Added asset  2155
# Added asset  2156
# Added asset  2157
# Added asset  2158
# Added asset  2159
# Added asset  2160
# Added asset  2161
# Added asset  2162
# Added asset  2163
# Added asset  2164
# Added asset  2165
# Added asset  2166
# Added asset  2167
# Added asset  2168
# Added asset  2169
# Added asset  2170
# Added asset  2171
# Added asset  2172
# Added asset  2173
# Added asset  2174
# Added asset  2175
# Added asset  2176
# Added asset  2177
# Added asset  2178
# Added asset  2179
# Added asset  2180
# Added asset  2181
# Added asset  2182
# Added asset  2183
# Added asset  2184
# Added asset  2185
# Added asset  2186
# Added asset  2187
# Added asset  2188
# Added asset  2189
# Added asset  2190
# Added asset  2191
# Added asset  2192
# Added asset  2193
# Added asset  2194
# Added asset  2195
# Added asset  2196
# Added asset  2197
# Added asset  2198
# Added asset  2199
# Added asset  2200
# Added asset  2201
# Added asset  2202
# Added asset  2203
# Added asset  2204
# Added asset  2205
# Added asset  2206
# Added asset  2207
# Added asset  2208
# Added asset  2209
# Added asset  2210
# Added asset  2211
# Added asset  2212
# Added asset  2213
# Added asset  2214
# Added asset  2215
# Added asset  2216
# Added asset  2217
# Added asset  2218
# Added asset  2219
# Added asset  2220
# Added asset  2221
# Added asset  2222
# Added asset  2223
# Added asset  2224
# Added asset  2225
# Added asset  2226
# Added asset  2227
# Added asset  2228
# Added asset  2229
# Added asset  2230
# Added asset  2231
# Added asset  2232
# Added asset  2233
# Added asset  2234
# Added asset  2235
# Added asset  2236
# Added asset  2237
# Added asset  2238
# Added asset  2239
# Added asset  2240
# Added asset  2241
# Added asset  2242
# Added asset  2243
# Added asset  2244
# Added asset  2245
# Added asset  2246
# Added asset  2247
# Added asset  2248
# Added asset  2249
# Added asset  2250
# Added asset  2251
# Added asset  2252
# Added asset  2253
# Added asset  2254
# Added asset  2255
# Added asset  2256
# Added asset  2257
# Added asset  2258
# Added asset  2259
# Added asset  2260
# Added asset  2261
# Added asset  2262
# Added asset  2263
# Added asset  2264
# Added asset  2265
# Added asset  2266
# Added asset  2267
# Added asset  2268
# Added asset  2269
# Added asset  2270
# Added asset  2271
# Added asset  2272
# Added asset  2273
# Added asset  2274
# Added asset  2275
# Added asset  2276
# Added asset  2277
# Added asset  2278
# Added asset  2279
# Added asset  2280
# Added asset  2281
# Added asset  2282
# Added asset  2283
# Added asset  2284
# Added asset  2285
# Added asset  2286
# Added asset  2287
# Added asset  2288
# Added asset  2289
# Added asset  2290
# Added asset  2291
# Added asset  2292
# Added asset  2293
# Added asset  2294
# Added asset  2295
# Added asset  2296
# Added asset  2297
# Added asset  2298
# Added asset  2299
# Added asset  2300
# Added asset  2301
# Added asset  2302
# Added asset  2303
# Added asset  2304
# Added asset  2305
# Added asset  2306
# Added asset  2307
# Added asset  2308
# Added asset  2309
# Added asset  2310
# Added asset  2311
# Added asset  2312
# Added asset  2313
# Added asset  2314
# Added asset  2315
# Added asset  2316
# Added asset  2317
# Added asset  2318
# Added asset  2319
# Added asset  2320
# Added asset  2321
# Added asset  2322
# Added asset  2323
# Added asset  2324
# Added asset  2325
# Added asset  2326
# Added asset  2327
# Added asset  2328
# Added asset  2329
# Added asset  2330
# Added asset  2331
# Added asset  2332
# Added asset  2333
# Added asset  2334
# Added asset  2335
# Added asset  2336
# Added asset  2337
# Added asset  2338
# Added asset  2339
# Added asset  2340
# Added asset  2341
# Added asset  2342
# Added asset  2343
# Added asset  2344
# Added asset  2345
# Added asset  2346
# Added asset  2347
# Added asset  2348
# Added asset  2349
# Added asset  2350
# Added asset  2351
# Added asset  2352
# Added asset  2353
# Added asset  2354
# Added asset  2355
# Added asset  2356
# Added asset  2357
# Added asset  2358
# Added asset  2359
# Added asset  2360
# Added asset  2361
# Added asset  2362
# Added asset  2363
# Added asset  2364
# Added asset  2365
# Added asset  2366
# Added asset  2367
# Added asset  2368
# Added asset  2369
# Added asset  2370
# Added asset  2371
# Added asset  2372
# Added asset  2373
# Added asset  2374
# Added asset  2375
# Added asset  2376
# Added asset  2377
# Added asset  2378
# Added asset  2379
# Added asset  2380
# Added asset  2381
# Added asset  2382
# Added asset  2383
# Added asset  2384
# Added asset  2385
# Added asset  2386
# Added asset  2387
# Added asset  2388
# Added asset  2389
# Added asset  2390
# Added asset  2391
# Added asset  2392
# Added asset  2393
# Added asset  2394
# Added asset  2395
# Added asset  2396
# Added asset  2397
# Added asset  2398
# Added asset  2399
# Added asset  2400
# Added asset  2401
# Added asset  2402
# Added asset  2403
# Added asset  2404
# Added asset  2405
# Added asset  2406
# Added asset  2407
# Added asset  2408
# Added asset  2409
# Added asset  2410
# Added asset  2411
# Added asset  2412
# Added asset  2413
# Added asset  2414
# Added asset  2415
# Added asset  2416
# Added asset  2417
# Added asset  2418
# Added asset  2419
# Added asset  2420
# Added asset  2421
# Added asset  2422
# Added asset  2423
# Added asset  2424
# Added asset  2425
# Added asset  2426
# Added asset  2427
# Added asset  2428
# Added asset  2429
# Added asset  2430
# Added asset  2431
# Added asset  2432
# Added asset  2433
# Added asset  2434
# Added asset  2435
# Added asset  2436
# Added asset  2437
# Added asset  2438
# Added asset  2439
# Added asset  2440
# Added asset  2441
# Added asset  2442
# Added asset  2443
# Added asset  2444
# Added asset  2445
# Added asset  2446
# Added asset  2447
# Added asset  2448
# Added asset  2449
# Added asset  2450
# Added asset  2451
# Added asset  2452
# Added asset  2453
# Added asset  2454
# Added asset  2455
# Added asset  2456
# Added asset  2457
# Added asset  2458
# Added asset  2459
# Added asset  2460
# Added asset  2461
# Added asset  2462
# Added asset  2463
# Added asset  2464
# Added asset  2465
# Added asset  2466
# Added asset  2467
# Added asset  2468
# Added asset  2469
# Added asset  2470
# Added asset  2471
# Added asset  2472
# Added asset  2473
# Added asset  2474
# Added asset  2475
# Added asset  2476
# Added asset  2477
# Added asset  2478
# Added asset  2479
# Added asset  2480
# Added asset  2481
# Added asset  2482
# Added asset  2483
# Added asset  2484
# Added asset  2485
# Added asset  2486
# Added asset  2487
# Added asset  2488
# Added asset  2489
# Added asset  2490
# Added asset  2491
# Added asset  2492
# Added asset  2493
# Added asset  2494
# Added asset  2495
# Added asset  2496
# Added asset  2497
# Added asset  2498
# Added asset  2499
# Added asset  2500
# Added asset  2501
# Added asset  2502
# Added asset  2503
# Added asset  2504
# Added asset  2505
# Added asset  2506
# Added asset  2507
# Added asset  2508
# Added asset  2509
# Added asset  2510
# Added asset  2511
# Added asset  2512
# Added asset  2513
# Added asset  2514
# Added asset  2515
# Added asset  2516
# Added asset  2517
# Added asset  2518
# Added asset  2519
# Added asset  2520
# Added asset  2521
# Added asset  2522
# Added asset  2523
# Added asset  2524
# Added asset  2525
# Added asset  2526
# Added asset  2527
# Added asset  2528
# Added asset  2529
# Added asset  2530
# Added asset  2531
# Added asset  2532
# Added asset  2533
# Added asset  2534
# Added asset  2535
# Added asset  2536
# Added asset  2537
# Added asset  2538
# Added asset  2539
# Added asset  2540
# Added asset  2541
# Added asset  2542
# Added asset  2543
# Added asset  2544
# Added asset  2545
# Added asset  2546
# Added asset  2547
# Added asset  2548
# Added asset  2549
# Added asset  2550
# Added asset  2551
# Added asset  2552
# Added asset  2553
# Added asset  2554
# Added asset  2555
# Added asset  2556
# Added asset  2557
# Added asset  2558
# Added asset  2559
# Added asset  2560
# Added asset  2561
# Added asset  2562
# Added asset  2563
# Added asset  2564
# Added asset  2565
# Added asset  2566
# Added asset  2567
# Added asset  2568
# Added asset  2569
# Added asset  2570
# Added asset  2571
# Added asset  2572
# Added asset  2573
# Added asset  2574
# Added asset  2575
# Added asset  2576
# Added asset  2577
# Added asset  2578
# Added asset  2579
# Added asset  2580
# Added asset  2581
# Added asset  2582
# Added asset  2583
# Added asset  2584
# Added asset  2585
# Added asset  2586
# Added asset  2587
# Added asset  2588
# Added asset  2589
# Added asset  2590
# Added asset  2591
# Added asset  2592
# Added asset  2593
# Added asset  2594
# Added asset  2595
# Added asset  2596
# Added asset  2597
# Added asset  2598
# Added asset  2599
# Added asset  2600
# Added asset  2601
# Added asset  2602
# Added asset  2603
# Added asset  2604
# Added asset  2605
# Added asset  2606
# Added asset  2607
# Added asset  2608
# Added asset  2609
# Added asset  2610
# Added asset  2611
# Added asset  2612
# Added asset  2613
# Added asset  2614
# Added asset  2615
# Added asset  2616
# Added asset  2617
# Added asset  2618
# Added asset  2619
# Added asset  2620
# Added asset  2621
# Added asset  2622
# Added asset  2623
# Added asset  2624
# Added asset  2625
# Added asset  2626
# Added asset  2627
# Added asset  2628
# Added asset  2629
# Added asset  2630
# Added asset  2631
# Added asset  2632
# Added asset  2633
# Added asset  2634
# Added asset  2635
# Added asset  2636
# Added asset  2637
# Added asset  2638
# Added asset  2639
# Added asset  2640
# Added asset  2641
# Added asset  2642
# Added asset  2643
# Added asset  2644
# Added asset  2645
# Added asset  2646
# Added asset  2647
# Added asset  2648
# Added asset  2649
# Added asset  2650
# Added asset  2651
# Added asset  2652
# Added asset  2653
# Added asset  2654
# Added asset  2655
# Added asset  2656
# Added asset  2657
# Added asset  2658
# Added asset  2659
# Added asset  2660
# Added asset  2661
# Added asset  2662
# Added asset  2663
# Added asset  2664
# Added asset  2665
# Added asset  2666
# Added asset  2667
# Added asset  2668
# Added asset  2669
# Added asset  2670
# Added asset  2671
# Added asset  2672
# Added asset  2673
# Added asset  2674
# Added asset  2675
# Added asset  2676
# Added asset  2677
# Added asset  2678
# Added asset  2679
# Added asset  2680
# Added asset  2681
# Added asset  2682
# Added asset  2683
# Added asset  2684
# Added asset  2685
# Added asset  2686
# Added asset  2687
# Added asset  2688
# Added asset  2689
# Added asset  2690
# Added asset  2691
# Added asset  2692
# Added asset  2693
# Added asset  2694
# Added asset  2695
# Added asset  2696
# Added asset  2697
# Added asset  2698
# Added asset  2699
# Added asset  2700
# Added asset  2701
# Added asset  2702
# Added asset  2703
# Added asset  2704
# Added asset  2705
# Added asset  2706
# Added asset  2707
# Added asset  2708
# Added asset  2709
# Added asset  2710
# Added asset  2711
# Added asset  2712
# Added asset  2713
# Added asset  2714
# Added asset  2715
# Added asset  2716
# Added asset  2717
# Added asset  2718
# Added asset  2719
# Added asset  2720
# Added asset  2721
# Added asset  2722
# Added asset  2723
# Added asset  2724
# Added asset  2725
# Added asset  2726
# Added asset  2727
# Added asset  2728
# Added asset  2729
# Added asset  2730
# Added asset  2731
# Added asset  2732
# Added asset  2733
# Added asset  2734
# Added asset  2735
# Added asset  2736
# Added asset  2737
# Added asset  2738
# Added asset  2739
# Added asset  2740
# Added asset  2741
# Added asset  2742
# Added asset  2743
# Added asset  2744
# Added asset  2745
# Added asset  2746
# Added asset  2747
# Added asset  2748
# Added asset  2749
# Added asset  2750
# Added asset  2751
# Added asset  2752
# Added asset  2753
# Added asset  2754
# Added asset  2755
# Added asset  2756
# Added asset  2757
# Added asset  2758
# Added asset  2759
# Added asset  2760
# Added asset  2761
# Added asset  2762
# Added asset  2763
# Added asset  2764
# Added asset  2765
# Added asset  2766
# Added asset  2767
# Added asset  2768
# Added asset  2769
# Added asset  2770
# Added asset  2771
# Added asset  2772
# Added asset  2773
# Added asset  2774
# Added asset  2775
# Added asset  2776
# Added asset  2777
# Added asset  2778
# Added asset  2779
# Added asset  2780
# Added asset  2781
# Added asset  2782
# Added asset  2783
# Added asset  2784
# Added asset  2785
# Added asset  2786
# Added asset  2787
# Added asset  2788
# Added asset  2789
# Added asset  2790
# Added asset  2791
# Added asset  2792
# Added asset  2793
# Added asset  2794
# Added asset  2795
# Added asset  2796
# Added asset  2797
# Added asset  2798
# Added asset  2799
# Added asset  2800
# Added asset  2801
# Added asset  2802
# Added asset  2803
# Added asset  2804
# Added asset  2805
# Added asset  2806
# Added asset  2807
# Added asset  2808
# Added asset  2809
# Added asset  2810
# Added asset  2811
# Added asset  2812
# Added asset  2813
# Added asset  2814
# Added asset  2815
# Added asset  2816
# Added asset  2817
# Added asset  2818
# Added asset  2819
# Added asset  2820
# Added asset  2821
# Added asset  2822
# Added asset  2823
# Added asset  2824
# Added asset  2825
# Added asset  2826
# Added asset  2827
# Added asset  2828
# Added asset  2829
# Added asset  2830
# Added asset  2831
# Added asset  2832
# Added asset  2833
# Added asset  2834
# Added asset  2835
# Added asset  2836
# Added asset  2837
# Added asset  2838
# Added asset  2839
# Added asset  2840
# Added asset  2841
# Added asset  2842
# Added asset  2843
# Added asset  2844
# Added asset  2845
# Added asset  2846
# Added asset  2847
# Added asset  2848
# Added asset  2849
# Added asset  2850
# Added asset  2851
# Added asset  2852
# Added asset  2853
# Added asset  2854
# Added asset  2855
# Added asset  2856
# Added asset  2857
# Added asset  2858
# Added asset  2859
# Added asset  2860
# Added asset  2861
# Added asset  2862
# Added asset  2863
# Added asset  2864
# Added asset  2865
# Added asset  2866
# Added asset  2867
# Added asset  2868
# Added asset  2869
# Added asset  2870
# Added asset  2871
# Added asset  2872
# Added asset  2873
# Added asset  2874
# Added asset  2875
# Added asset  2876
# Added asset  2877
# Added asset  2878
# Added asset  2879
# Added asset  2880
# Added asset  2881
# Added asset  2882
# Added asset  2883
# Added asset  2884
# Added asset  2885
# Added asset  2886
# Added asset  2887
# Added asset  2888
# Added asset  2889
# Added asset  2890
# Added asset  2891
# Added asset  2892
# Added asset  2893
# Added asset  2894
# Added asset  2895
# Added asset  2896
# Added asset  2897
# Added asset  2898
# Added asset  2899
# Added asset  2900
# Added asset  2901
# Added asset  2902
# Added asset  2903
# Added asset  2904
# Added asset  2905
# Added asset  2906
# Added asset  2907
# Added asset  2908
# Added asset  2909
# Added asset  2910
# Added asset  2911
# Added asset  2912
# Added asset  2913
# Added asset  2914
# Added asset  2915
# Added asset  2916
# Added asset  2917
# Added asset  2918
# Added asset  2919
# Added asset  2920
# Added asset  2921
# Added asset  2922
# Added asset  2923
# Added asset  2924
# Added asset  2925
# Added asset  2926
# Added asset  2927
# Added asset  2928
# Added asset  2929
# Added asset  2930
# Added asset  2931
# Added asset  2932
# Added asset  2933
# Added asset  2934
# Added asset  2935
# Added asset  2936
# Added asset  2937
# Added asset  2938
# Added asset  2939
# Added asset  2940
# Added asset  2941
# Added asset  2942
# Added asset  2943
# Added asset  2944
# Added asset  2945
# Added asset  2946
# Added asset  2947
# Added asset  2948
# Added asset  2949
# Added asset  2950
# Added asset  2951
# Added asset  2952
# Added asset  2953
# Added asset  2954
# Added asset  2955
# Added asset  2956
# Added asset  2957
# Added asset  2958
# Added asset  2959
# Added asset  2960
# Added asset  2961
# Added asset  2962
# Added asset  2963
# Added asset  2964
# Added asset  2965
# Added asset  2966
# Added asset  2967
# Added asset  2968
# Added asset  2969
# Added asset  2970
# Added asset  2971
# Added asset  2972
# Added asset  2973
# Added asset  2974
# Added asset  2975
# Added asset  2976
# Added asset  2977
# Added asset  2978
# Added asset  2979
# Added asset  2980
# Added asset  2981
# Added asset  2982
# Added asset  2983
# Added asset  2984
# Added asset  2985
# Added asset  2986
# Added asset  2987
# Added asset  2988
# Added asset  2989
# Added asset  2990
# Added asset  2991
# Added asset  2992
# Added asset  2993
# Added asset  2994
# Added asset  2995
# Added asset  2996
# Added asset  2997
# Added asset  2998
# Added asset  2999
# Added asset  3000
# Added asset  3001
# Added asset  3002
# Added asset  3003
# Added asset  3004
# Added asset  3005
# Added asset  3006
# Added asset  3007
# Added asset  3008
# Added asset  3009
# Added asset  3010
# Added asset  3011
# Added asset  3012
# Added asset  3013
# Added asset  3014
# Added asset  3015
# Added asset  3016
# Added asset  3017
# Added asset  3018
# Added asset  3019
# Added asset  3020
# Added asset  3021
# Added asset  3022
# Added asset  3023
# Added asset  3024
# Added asset  3025
# Added asset  3026
# Added asset  3027
# Added asset  3028
# Added asset  3029
# Added asset  3030
# Added asset  3031
# Added asset  3032
# Added asset  3033
# Added asset  3034
# Added asset  3035
# Added asset  3036
# Added asset  3037
# Added asset  3038
# Added asset  3039
# Added asset  3040
# Added asset  3041
# Added asset  3042
# Added asset  3043
# Added asset  3044
# Added asset  3045
# Added asset  3046
# Added asset  3047
# Added asset  3048
# Added asset  3049
# Added asset  3050
# Added asset  3051
# Added asset  3052
# Added asset  3053
# Added asset  3054
# Added asset  3055
# Added asset  3056
# Added asset  3057
# Added asset  3058
# Added asset  3059
# Added asset  3060
# Added asset  3061
# Added asset  3062
# Added asset  3063
# Added asset  3064
# Added asset  3065
# Added asset  3066
# Added asset  3067
# Added asset  3068
# Added asset  3069
# Added asset  3070
# Added asset  3071
# Added asset  3072
# Added asset  3073
# Added asset  3074
# Added asset  3075
# Added asset  3076
# Added asset  3077
# Added asset  3078
# Added asset  3079
# Added asset  3080
# Added asset  3081
# Added asset  3082
# Added asset  3083
# Added asset  3084
# Added asset  3085
# Added asset  3086
# Added asset  3087
# Added asset  3088
# Added asset  3089
# Added asset  3090
# Added asset  3091
# Added asset  3092
# Added asset  3093
# Added asset  3094
# Added asset  3095
# Added asset  3096
# Added asset  3097
# Added asset  3098
# Added asset  3099
# Added asset  3100
# Added asset  3101
# Added asset  3102
# Added asset  3103
# Added asset  3104
# Added asset  3105
# Added asset  3106
# Added asset  3107
# Added asset  3108
# Added asset  3109
# Added asset  3110
# Added asset  3111
# Added asset  3112
# Added asset  3113
# Added asset  3114
# Added asset  3115
# Added asset  3116
# Added asset  3117
# Added asset  3118
# Added asset  3119
# Added asset  3120
# Added asset  3121
# Added asset  3122
# Added asset  3123
# Added asset  3124
# Added asset  3125
# Added asset  3126
# Added asset  3127
# Added asset  3128
# Added asset  3129
# Added asset  3130
# Added asset  3131
# Added asset  3132
# Added asset  3133
# Added asset  3134
# Added asset  3135
# Added asset  3136
# Added asset  3137
# Added asset  3138
# Added asset  3139
# Added asset  3140
# Added asset  3141
# Added asset  3142
# Added asset  3143
# Added asset  3144
# Added asset  3145
# Added asset  3146
# Added asset  3147
# Added asset  3148
# Added asset  3149
# Added asset  3150
# Added asset  3151
# Added asset  3152
# Added asset  3153
# Added asset  3154
# Added asset  3155
# Added asset  3156
# Added asset  3157
# Added asset  3158
# Added asset  3159
# Added asset  3160
# Added asset  3161
# Added asset  3162
# Added asset  3163
# Added asset  3164
# Added asset  3165
# Added asset  3166
# Added asset  3167
# Added asset  3168
# Added asset  3169
# Added asset  3170
# Added asset  3171
# Added asset  3172
# Added asset  3173
# Added asset  3174
# Added asset  3175
# Added asset  3176
# Added asset  3177
# Added asset  3178
# Added asset  3179
# Added asset  3180
# Added asset  3181
# Added asset  3182
# Added asset  3183
# Added asset  3184
# Added asset  3185
# Added asset  3186
# Added asset  3187
# Added asset  3188
# Added asset  3189
# Added asset  3190
# Added asset  3191
# Added asset  3192
# Added asset  3193
# Added asset  3194
# Added asset  3195
# Added asset  3196
# Added asset  3197
# Added asset  3198
# Added asset  3199
# Added asset  3200
# Added asset  3201
# Added asset  3202
# Added asset  3203
# Added asset  3204
# Added asset  3205
# Added asset  3206
# Added asset  3207
# Added asset  3208
# Added asset  3209
# Added asset  3210
# Added asset  3211
# Added asset  3212
# Added asset  3213
# Added asset  3214
# Added asset  3215
# Added asset  3216
# Added asset  3217
# Added asset  3218
# Added asset  3219
# Added asset  3220
# Added asset  3221
# Added asset  3222
# Added asset  3223
# Added asset  3224
# Added asset  3225
# Added asset  3226
# Added asset  3227
# Added asset  3228
# Added asset  3229
# Added asset  3230
# Added asset  3231
# Added asset  3232
# Added asset  3233
# Added asset  3234
# Added asset  3235
# Added asset  3236
# Added asset  3237
# Added asset  3238
#
# Calculated price elasticity
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'inv_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_liquidity = calc_price_elasticity(df_result.loc[df_result['date'] == df_result['date'].median()])
#
# Cell In[27], line 58, in calc_price_elasticity(df_results)
#      51 mask = df_results['holding'] > 0
#      53 df_liquidity = (df_results
#      54                 .loc[mask]
#      55                 .groupby('date')
#      56                 .apply(calc_coliquidity_matrix))
# ---> 58 log_liquidity(df_liquidity)
#      59 return df_liquidity
#
# Cell In[8], line 201, in log_liquidity(df_liquidity)
#     199 print()
#     200 print('Calculated price elasticity')
# --> 201 print('Number of investors:  ', df_liquidity['inv_id'].nunique())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'inv_id'

# %%
df_liquidity.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_liquidity.describe()
#
# NameError: name 'df_liquidity' is not defined

# %%
print('\n---------------Starting Imports---------------------------\n')
dfs = pandas_read(input_path)

# %%
print('\n---------------Starting Cleaning---------------------------\n')
df_s12_clean, df_s12type5_clean, df_s34_clean, df_beta_clean, df_security_clean = clean_imports(
    *dfs,
    start_date,
    end_date
)

# df_s12_clean.to_csv(os.path.join(output_path, 'df_s12_clean.csv'))
# df_s12type5_clean.to_csv(os.path.join(output_path, 'df_s12type5_clean.csv'))
# df_s34_clean.to_csv(os.path.join(output_path, 'df_s34_clean.csv'))
# df_beta_clean.to_csv(os.path.join(output_path, 'df_beta_clean.csv'))
# df_security_clean.to_csv(os.path.join(output_path, 'df_security_clean.csv'))

# %%
print('\n---------------Merging Assets/Factors---------------------------\n')
df_asset = merge_assets_factors(df_security_clean, df_beta_clean)
# df_asset.to_csv(os.path.join(output_path, 'df_asset.csv'))

print('\n---------------Merging s12/s34 Holdings---------------------------\n')
df_fund_manager = match_fund_manager(df_s12_clean, df_s34_clean, df_s12type5_clean)
# df_fund_manager.to_csv(os.path.join(output_path, 'df_fund_manager.csv'))

# %%
print('\n---------------Constructing Zero Holdings---------------------------\n')
df_holding = construct_zero_holdings(df_fund_manager, n_quarters)
# df_holding.to_csv(os.path.join(output_path, 'df_holding.csv'))

# %%
print('\n---------------Merging Holdings/Factors---------------------------\n')
df_holding_factor = merge_holding_factor(df_holding, df_asset)
# df_holding_factor.to_csv(os.path.join(output_path, 'df_holding_factor.csv'))

# %%
print('\n---------------Dropping Mangers/Assets Without Holdings---------------------------\n')
df_dropped = drop_unsused_inv_asset(df_holding_factor)
# df_holding.to_csv(os.path.join(output_path, 'df_holding.csv'))

print('\n---------------Creating Household Sector---------------------------\n')
df_household = create_household_sector(df_dropped)
# df_household.to_csv(os.path.join(output_path, 'df_household.csv'))

print('\n---------------Partitioning Outside Asset---------------------------\n')
df_outside = partition_outside_asset(df_household)
# df_outside.to_csv(os.path.join(output_path, 'df_outside.csv'))

# %%
print('\n---------------Calculating Investor AUM---------------------------\n')
df_inv_aum = calc_inv_aum(df_outside)
# df_inv_aum.to_csv(os.path.join(output_path, 'df_inv_aum.csv'))

# %%
print('\n---------------Aggregating Small Investors---------------------------\n')
df_agg = agg_small_inv(df_inv_aum)
# df_agg.to_csv(os.path.join(output_path, 'df_agg.csv'))

# %%
print('\n---------------Pooling Investors By Type/Size---------------------------\n')
df_binned = bin_inv(df_agg, min_n_holding)
# df_binned.to_csv(os.path.join(output_path, 'df_binned.csv'))

# %%
print('\n---------------Calculating Instrument---------------------------\n')
df_instrument = calc_instrument(df_binned)
# df_instrument.to_csv(os.path.join(output_path, 'df_instrument.csv'))

# %%
print('\n---------------Calculating Holding Weights---------------------------\n')
df_weights = calc_holding_weights(df_instrument)
# df_weights.to_csv(os.path.join(output_path, 'df_weights.csv'))

# %%
print('\n---------------Estimating Demand System---------------------------\n')
df_model = estimate_model_L(df_weights, characteristics, params, min_n_holding)
# df_model.to_csv(os.path.join(output_path, 'df_model.csv'))

# %%
print('\n---------------Calculating Latent Demand---------------------------\n')
df_results = calc_latent_demand_L(df_model, characteristics, params)
# df_results.to_csv(os.path.join(output_path, 'df_results.csv'))

# %%
print('\n---------------Testing Moment Condition---------------------------\n')
# df_figures = clean_figures(df_results)
# _ = check_moment_condition(df_figures, 0, min_n_holding)

# %%
print('\n---------------Investors by Typecode---------------------------\n')
# _ = typecode_share_counts(df_figures, figure_path)

# %%
print('\n---------------Testing Instrument Validity---------------------------\n')
# _ = critical_value_test(df_figures, characteristics, min_n_holding, figure_path)

# %%
print('\n---------------Testing Hypothetical Index Fund---------------------------\n')
# _ = test_index_fund(df_figures, characteristics, params, indexfund_id, figure_path)

# %%
print('\n---------------Parameters By Typecode---------------------------\n')
# _ = graph_type_params(df_figures, params, figure_path)

# %%
print('\n---------------Standard Deviation of Latent Demand By Typecode---------------------------\n')
# _ = graph_std_latent_demand(df_figures, figure_path)

# %%
print('\n---------------Calculating Price Elasticity---------------------------\n')
df_liquidity = calc_price_elasticity(df_results).pipe(graph_liquidity)

# %%
print('\n---------------Testing Predictability---------------------------\n')

# %%
print('\n---------------Simulating Monetary Policy Shock---------------------------\n')

# %%
print('\n---------------Finished---------------------------\n')
